# %% [markdown]
# # 제2회 통신망 안정성 확보를 위한 인공지능 해커톤
# # 분야 1 :무선 기지국 장비의 통계 데이터를 활용한 인구 밀집도 예측

# %% [markdown]
# - 출제 배경<br>
#     : 많은 사람들이 특정 시간/장소에 모이면 무선 통신 품질의 저하와 함께 각종 사고 위험으로부터 안전할 수 없게 됩니다. 통신사업자의 무선 통신 기지국에서는 서비스를 제공하는 단말의 통계 정보를 통해 인구의 밀집 정도를 파악 가능합니다. 무선 네트워크의 성능을 안정적으로 유지하고 인구 밀집도를 완화하기 위해, AI를 활용하여 특정 축제 지역 내의 인구 수를 예측하고자 합니다.
# - 학습 데이터<br>
#     : 무선 기지국 장비인 RU(Radio Unit)에서는 서비스 지역인 셀 내에 존재하는 단말들의 통계 데이터를 관리합니다. 본 데이터에서는 업링크/다운링크 데이터 크기 및 블록 오류율(BLER), 셀 내 평균 수신 신호 강도(RSSI) 및 사용자 단말 수 등의 각종 통계 정보가 5분 단위로 제공됩니다.
# - 문제 구성 및 풀이 요령<br>
#     : 축제 지역 근방 10곳의 기지국에서 축제 기간 전후에 해당하는 모든 타임스탬프에 대해 인구 수를 예측하는 회귀 문제입니다. 다양한 데이터 컬럼 중 인구 수 변화에 유의미한 값을 선별하고 시계열 데이터의 주기성을 고려하는 것이 중요합니다. 인구 1인당 단말 1대를 가지고 있다고 가정합니다.
# - 채점 기준<br>
#     : 평균 절대 오차(MAE)

# %% [markdown]
# # Import

# %%
# # AUTOML 관련 패키지 설치
# !pip install autogluon
# # 설치 후 런타임 재시작

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import warnings
from autogluon.tabular import TabularDataset, TabularPredictor # autogluon

pd.options.display.max_columns = None
warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# 해당 경로는 저장 위치에 따라 변경
# %cd '/content/drive/MyDrive/colab/제2회 통신망 안정성 확보를 위한 인공지능 해커톤/Q1'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/colab/제2회 통신망 안정성 확보를 위한 인공지능 해커톤/Q1

# %% [markdown]
# # Submit 1 : 상관관계 높은 컬럼 사용 / 로그 스케일링 / 이상치 제거 / 정규화

# %% [markdown]
# ## 01) data set load

# %%
train_merge_f = pd.read_csv('preprocessed_data/submit1_train.csv', index_col=0)
x_test_merge_f = pd.read_csv('preprocessed_data/submit1_test.csv', index_col=0)

# %%
train_merge_f.head()
# Out:
#     scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0 -0.650928   -0.832874    -0.832691   -0.096652    -0.096512
# 1 -0.657152    0.324175     0.324511    0.682312     0.682469
# 2  1.030015   -0.426198    -0.425954   -0.424311    -0.424243
# 3 -0.406465   -1.114238    -1.113994   -0.976695    -0.976614
# 4 -0.561473    0.803532     0.803636    0.974515     0.974593
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -1.790962          -1.552873         -3.350626          -3.353591
# 1          1.310287           1.618175          1.100066           1.077706
# 2          0.612832           0.631136         -0.628696          -0.615033
# 3         -0.826929          -0.781595         -1.818113          -1.813472
# 4          0.593810           0.596539          0.709139           0.721250
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0     -0.268361      -0.264663                     -0.418631
# 1     -0.986157      -0.983742                     -0.511178
# 2     -2.072921      -2.070899                      1.000958
# 3      1.005675       1.008167                     -0.312775
# 4     -0.815109      -0.813346                     -0.246645
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                     -0.324742    -1.738269     -1.735410           0
# 1                     -0.235394    -0.984750     -0.984162           0
# 2                     -0.479227    -1.311945     -1.309987           0
# 3                     -0.183432    -0.688403     -0.687824           0
# 4                     -0.207081     0.780193      0.780557           0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0            0  -3.713571  -3.834820    -1.315288    -1.154916
# 1            0   0.255654   0.472608     0.033991     0.222232
# 2            0   0.631021   0.388912     0.515251    -0.045995
# 3            0  -0.487264  -0.623035    -0.544307    -0.590302
# 4            0   0.306237   0.848377    -0.019062     0.465122
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -0.524373     -2.750116     -2.937247      -1.066092 -1.066092
# 1        -0.949112     -0.033831      0.489980       1.216417  1.216417
# 2         1.262533      0.700004      0.306421      -0.268890 -0.268890
# 3        -0.708825     -0.599738     -0.756642       2.114622  2.114622
# 4        -0.507213      0.144306      0.884744       0.554075  0.554075
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb  uenomax
# 0 -1.201694  -0.975277    -1.160101         -0.817691      -1.330158        1
# 1  0.368558  -0.976752    -0.626002         -0.573283       1.419193        5
# 2 -0.446870  -1.058652    -1.035583         -0.283147      -0.633761        6
# 3 -0.438913  -0.859361    -2.259611          0.915922      -0.575646        1
# 4  0.729070  -1.020477    -1.546140          1.869399       0.963641        4

# %%
x_test_merge_f.head()
# Out:
#     scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0 -0.667542   -0.481082    -0.480596   -0.257629    -0.257425
# 1 -0.427040   -1.454413    -1.453854   -1.349899    -1.349338
# 2 -0.667542   -1.004315    -1.003808   -1.144738    -1.144495
# 3 -0.427040    0.447827     0.448464    0.530739     0.531318
# 4 -0.667542   -0.716359    -0.715864   -0.490970    -0.490755
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -0.718056          -0.670180         -1.382757          -1.379720
# 1         -1.000441          -0.916495         -1.413417          -1.410143
# 2         -0.718056          -0.670180         -0.328479          -0.324267
# 3         -1.000441          -0.916495          0.464955           0.470439
# 4         -0.718056          -0.670180         -0.916231          -0.912675
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0      0.010077       0.011238                     -0.226592
# 1     -0.469494      -0.468596                     -0.128414
# 2      0.010077       0.011238                     -0.226592
# 3     -0.469494      -0.468596                     -0.128414
# 4      0.573040       0.574515                     -0.226592
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                     -0.171584     1.982971      1.987162           0
# 1                     -0.086296    -0.447929     -0.447758           0
# 2                     -0.171584    -0.323645     -0.322739           0
# 3                     -0.086296    -0.447929     -0.447758           0
# 4                     -0.171584    -0.323645     -0.322739           0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0            0  -1.562210  -1.751742    -0.410825    -0.523185
# 1            0  -1.509133  -1.624831    -0.469801    -0.633370
# 2            0   0.529450  -0.234396    -0.410825    -0.523185
# 3            0   0.132145  -0.138808    -0.469801    -0.633370
# 4            0   0.251629  -0.391863    -0.410825    -0.523185
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -1.070125     -0.602207     -0.271383       0.375598  0.375598
# 1         0.278680     -1.920447     -1.815504      -1.467930 -1.467930
# 2         2.216891      0.324410     -0.267118      -0.652779 -0.652779
# 3        -0.835845     -0.060003     -0.204914       0.089064  0.089064
# 4        -0.193587     -0.107811     -0.508853      -0.065758 -0.065758
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb
# 0 -0.332304  -0.859361    -0.318702         -0.011695      -0.577303
# 1 -1.201107  -1.020477    -0.298595         -1.559757      -1.002757
# 2  0.489501  -0.919680    -0.415243          0.862119      -0.577303
# 3  0.278165  -1.084683    -0.298595         -0.750170       0.398415
# 4 -0.506874  -0.984066    -0.415243          0.586177      -0.577303

# %%
# train set, test set autogluon input dataset 으로 변경
train_data = TabularDataset(train_merge_f)
test_data = TabularDataset(x_test_merge_f)

# %% [markdown]
# ## 02) autogluon modeling

# %%
# 모델 서칭
save_path = 'aj_predictmodel1' # 모델.pkl 파일 저장 경로
predictor = TabularPredictor(label='uenomax', problem_type='regression', path=save_path, eval_metric='mean_absolute_error').fit(train_data, presets='best_quality', num_bag_folds=5, num_bag_sets=1) # 예측 모델 찾기
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="aj_predictmodel1"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (113432 samples, 29.95 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "aj_predictmodel1/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Jun 9 10:57:30 UTC 2023
# Disk Space Avail:   33.55 GB / 107.37 GB (31.2%)
# Train Data Rows:    113432
# Train Data Columns: 31
# Label Column: uenomax
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    52941.52 MB
# 	Train Data (Original)  Memory Usage: 28.13 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['numrar']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['numrar']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', [])   :  2 | ['reestabatt', 'reestabsucc']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', ['bool']) :  2 | ['reestabatt', 'reestabsucc']
# 	0.8s = Fit runtime
# 	30 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 25.64 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.89s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-1.0103	 = Validation score   (-mean_absolute_error)
# 	0.1s	 = Training   runtime
# 	15.28s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-1.0069	 = Validation score   (-mean_absolute_error)
# 	0.09s	 = Training   runtime
# 	16.05s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6158	 = Validation score   (-mean_absolute_error)
# 	95.25s	 = Training   runtime
# 	60.96s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6146	 = Validation score   (-mean_absolute_error)
# 	48.66s	 = Training   runtime
# 	18.23s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.6208	 = Validation score   (-mean_absolute_error)
# 	131.09s	 = Training   runtime
# 	5.96s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6092	 = Validation score   (-mean_absolute_error)
# 	304.39s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.6225	 = Validation score   (-mean_absolute_error)
# 	31.72s	 = Training   runtime
# 	5.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6313	 = Validation score   (-mean_absolute_error)
# 	174.33s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6176	 = Validation score   (-mean_absolute_error)
# 	35.36s	 = Training   runtime
# 	3.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5893	 = Validation score   (-mean_absolute_error)
# 	510.86s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6138	 = Validation score   (-mean_absolute_error)
# 	58.57s	 = Training   runtime
# 	23.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.5875	 = Validation score   (-mean_absolute_error)
# 	1.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6065	 = Validation score   (-mean_absolute_error)
# 	13.18s	 = Training   runtime
# 	2.64s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6039	 = Validation score   (-mean_absolute_error)
# 	9.15s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.6087	 = Validation score   (-mean_absolute_error)
# 	275.69s	 = Training   runtime
# 	7.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6046	 = Validation score   (-mean_absolute_error)
# 	28.36s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.6062	 = Validation score   (-mean_absolute_error)
# 	48.29s	 = Training   runtime
# 	7.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6012	 = Validation score   (-mean_absolute_error)
# 	173.63s	 = Training   runtime
# 	2.35s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6015	 = Validation score   (-mean_absolute_error)
# 	7.78s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5788	 = Validation score   (-mean_absolute_error)
# 	509.17s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6051	 = Validation score   (-mean_absolute_error)
# 	18.81s	 = Training   runtime
# 	1.89s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.5786	 = Validation score   (-mean_absolute_error)
# 	1.6s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2616.52s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("aj_predictmodel1/")

# %%
# best model load
predictor = TabularPredictor.load('aj_predictmodel1/')

# %%
# 개별 모델의 train 성능 확인
ld_board = predictor.leaderboard(train_data, silent=True)
ld_board=ld_board.sort_values(by='score_val',ascending=False)

# %%
ld_board
# Out:
#                      model    score_test  score_val  pred_time_test  \
# 4      WeightedEnsemble_L3 -4.321677e-01  -0.578554      200.571017
# 3    NeuralNetTorch_BAG_L2 -4.317649e-01  -0.578848      192.718829
# 16     WeightedEnsemble_L2 -5.193677e-01  -0.587493       63.343241
# 17   NeuralNetTorch_BAG_L1 -5.313509e-01  -0.589308        2.558141
# 11  NeuralNetFastAI_BAG_L2 -4.869839e-01  -0.601192      203.957915
# 13          XGBoost_BAG_L2 -4.907488e-01  -0.601483      189.405494
# 12         LightGBM_BAG_L2 -4.877279e-01  -0.603856      188.894630
# 9          CatBoost_BAG_L2 -4.808473e-01  -0.604611      187.550742
# 7     LightGBMLarge_BAG_L2 -4.774850e-01  -0.605125      191.616407
# 6     ExtraTreesMSE_BAG_L2 -4.755182e-01  -0.606215      191.190409
# 10       LightGBMXT_BAG_L2 -4.830231e-01  -0.606493      191.575875
# 8   RandomForestMSE_BAG_L2 -4.776681e-01  -0.608656      191.328310
# 18         CatBoost_BAG_L1 -5.323032e-01  -0.609205        0.916787
# 5     LightGBMLarge_BAG_L1 -4.593993e-01  -0.613812       30.173604
# 15         LightGBM_BAG_L1 -5.168859e-01  -0.614585       23.163855
# 14       LightGBMXT_BAG_L1 -5.161917e-01  -0.615836       72.910755
# 19          XGBoost_BAG_L1 -5.336517e-01  -0.617575        4.696133
# 1   RandomForestMSE_BAG_L1 -2.925893e-01  -0.620758        6.519363
# 2     ExtraTreesMSE_BAG_L1 -3.571424e-01  -0.622458        3.956606
# 20  NeuralNetFastAI_BAG_L1 -6.102610e-01  -0.631335        9.767520
# 0    KNeighborsDist_BAG_L1 -2.017314e-08  -1.006882       16.565693
# 21   KNeighborsUnif_BAG_L1 -8.188360e-01  -1.010290       16.114125
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 4      167.213305  2225.167214                 0.018635
# 3      152.767797  1899.581012                 5.376245
# 16      48.391464  1055.487601                 0.011490
# 17       0.815364   510.861580                 2.558141
# 11     154.009830  1564.039213                16.615332
# 13     152.437626  1398.198838                 2.062911
# 12     152.553315  1399.567073                 1.552047
# 9      151.736341  1418.772259                 0.208159
# 7      153.553452  1409.227131                 4.273824
# 6      158.716610  1438.707139                 3.847826
# 10     154.297930  1403.589119                 4.233292
# 8      159.048517  1666.106457                 3.985727
# 18       0.236326   304.391585                 0.916787
# 5       23.149083    58.568165                30.173604
# 15      18.227983    48.655374                23.163855
# 14      60.958215    95.253114                72.910755
# 19       3.180320    35.356719                 4.696133
# 1        5.960396   131.085367                 6.519363
# 2        5.504658    31.723050                 3.956606
# 20       2.295267   174.331600                 9.767520
# 0       16.048442     0.086243                16.565693
# 21      15.284892     0.101161                16.114125
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 4                 0.002272           1.600520            3       True
# 3                 1.106852         509.167055            2       True
# 16                0.002311           1.925530            2       True
# 17                0.815364         510.861580            1       True
# 11                2.348884         173.625256            2       True
# 13                0.776681           7.784882            2       True
# 12                0.892370           9.153116            2       True
# 9                 0.075395          28.358302            2       True
# 7                 1.892506          18.813174            2       True
# 6                 7.055665          48.293183            2       True
# 10                2.636985          13.175163            2       True
# 8                 7.387571         275.692500            2       True
# 18                0.236326         304.391585            1       True
# 5                23.149083          58.568165            1       True
# 15               18.227983          48.655374            1       True
# 14               60.958215          95.253114            1       True
# 19                3.180320          35.356719            1       True
# 1                 5.960396         131.085367            1       True
# 2                 5.504658          31.723050            1       True
# 20                2.295267         174.331600            1       True
# 0                16.048442           0.086243            1       True
# 21               15.284892           0.101161            1       True
#
#     fit_order
# 4          22
# 3          20
# 16         12
# 17         10
# 11         18
# 13         19
# 12         14
# 9          16
# 7          21
# 6          17
# 10         13
# 8          15
# 18          6
# 5          11
# 15          4
# 14          3
# 19          9
# 1           5
# 2           7
# 20          8
# 0           2
# 21          1

# %%
# predict
y_test = predictor.predict(test_data)

# %%
y_test.head()
# Out:
# 0    3.039357
# 1    1.184619
# 2    3.762382
# 3    3.470598
# 4    3.671516
# Name: uenomax, dtype: float32

# %% [markdown]
# ## 03) make submit file

# %%
# x_test + y_test
test = pd.read_csv('raw_data/Q1_test.csv')
pred = test.loc[:,['ru_id']]
pred['pred'] = y_test

# make submit file
submit = pd.read_csv('raw_data/Q1_label_sample.csv')
submit['BaseStationB']=pred.loc[pred['ru_id']=='BaseStationB',['pred']].reset_index(drop=True)
submit['BaseStationJ']=pred.loc[pred['ru_id']=='BaseStationJ',['pred']].reset_index(drop=True)

# 함수 돌리기 전에 순서바꿔야함
submit.to_csv('submission_data/submit1.csv')
submit.head()
# Out:
#               datetime  BaseStationB  BaseStationJ
# 0  2023-05-19 00:00:00      1.184619      3.039357
# 1  2023-05-19 00:05:00      3.470598      3.762382
# 2  2023-05-19 00:10:00      3.716020      3.671516
# 3  2023-05-19 00:15:00      2.945974      4.099239
# 4  2023-05-19 00:20:00      3.294462      4.687873

# %% [markdown]
# ## 제출 결과 : 1.532884604점

# %% [markdown]
# # Submit2 : 상관관계 높은 컬럼 사용 / 로그 스케일링 / 정규화

# %% [markdown]
# ## 01) data set load

# %%
train_merge_f = pd.read_csv('preprocessed_data/submit2_train.csv', index_col=0)
x_test_merge_f = pd.read_csv('preprocessed_data/submit2_test.csv', index_col=0)

# %%
train_merge_f.head()
# Out:
#     scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0 -0.642055   -0.832913    -0.832730   -0.096805    -0.096665
# 1 -0.633315    0.323117     0.323452    0.680445     0.680602
# 2  0.992809   -0.426198    -0.425954   -0.424311    -0.424243
# 3 -0.406465   -1.114238    -1.113994   -0.976695    -0.976614
# 4 -0.556887    0.803532     0.803636    0.974515     0.974593
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -1.788567          -1.531903         -3.349084          -3.352038
# 1          1.310287           1.606385          1.097706           1.074189
# 2          0.612405           0.629271         -0.628696          -0.615033
# 3         -0.826728          -0.778351         -1.817508          -1.812862
# 4          0.586366           0.370437          0.708844           0.720950
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0     -0.268580      -0.264883                     -0.418631
# 1     -0.986157      -0.983742                     -0.511178
# 2     -2.072355      -2.070336                      0.980891
# 3      0.996785       0.999245                     -0.312775
# 4     -0.815109      -0.813346                     -0.246645
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                     -0.324742    -1.738269     -1.735410           0
# 1                     -0.235394    -0.984477     -0.983888           0
# 2                     -0.479227    -1.311945     -1.309987           0
# 3                     -0.183432    -0.684746     -0.684214           0
# 4                     -0.207081     0.613963      0.615916           0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0            0  -3.682557  -3.832811    -0.944992    -0.924894
# 1            0   0.247800   0.469808    -0.118880    -0.005310
# 2            0   0.581540   0.386094     0.245136    -0.099470
# 3            0  -0.487264  -0.623035    -0.454600    -0.442444
# 4            0   0.304983   0.848377    -0.111756     0.135980
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -0.525700     -2.722273     -2.934820      -1.065644 -1.065644
# 1        -0.940073     -0.043042      0.484373       1.216417  1.216417
# 2         1.250790      0.642649      0.303265      -0.269324 -0.269324
# 3        -0.718960     -0.599815     -0.756642       2.061341  2.061341
# 4        -0.511826      0.139361      0.884744       0.542622  0.542622
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb  uenomax
# 0 -1.200997  -0.975277    -0.622757         -0.817923      -1.330158        1
# 1  0.368558  -0.976752    -0.299750         -0.574049       1.415736        5
# 2 -0.446870  -1.058652    -0.695473         -0.291506      -0.633810        6
# 3 -0.438986  -0.859361    -0.439955          0.915922      -0.575182        1
# 4  0.723794  -1.020477    -0.463952          1.735165       0.963641        4

# %%
x_test_merge_f.head()
# Out:
#     scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0 -0.667542   -0.481082    -0.480596   -0.257629    -0.257425
# 1 -0.427040   -1.454413    -1.453854   -1.349899    -1.349338
# 2 -0.667542   -1.004315    -1.003808   -1.144738    -1.144495
# 3 -0.427040    0.447827     0.448464    0.530739     0.531318
# 4 -0.667542   -0.716359    -0.715864   -0.490970    -0.490755
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -0.718056          -0.670180         -1.382757          -1.379720
# 1         -1.000441          -0.916495         -1.413417          -1.410143
# 2         -0.718056          -0.670180         -0.328479          -0.324267
# 3         -1.000441          -0.916495          0.464955           0.470439
# 4         -0.718056          -0.670180         -0.916231          -0.912675
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0      0.010077       0.011238                     -0.226592
# 1     -0.469494      -0.468596                     -0.128414
# 2      0.010077       0.011238                     -0.226592
# 3     -0.469494      -0.468596                     -0.128414
# 4      0.573040       0.574515                     -0.226592
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                     -0.171584     1.982971      1.987162           0
# 1                     -0.086296    -0.447929     -0.447758           0
# 2                     -0.171584    -0.323645     -0.322739           0
# 3                     -0.086296    -0.447929     -0.447758           0
# 4                     -0.171584    -0.323645     -0.322739           0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0            0  -1.562210  -1.751742    -0.410825    -0.523185
# 1            0  -1.509133  -1.624831    -0.469801    -0.633370
# 2            0   0.529450  -0.234396    -0.410825    -0.523185
# 3            0   0.132145  -0.138808    -0.469801    -0.633370
# 4            0   0.251629  -0.391863    -0.410825    -0.523185
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -1.070125     -0.602207     -0.271383       0.375598  0.375598
# 1         0.278680     -1.920447     -1.815504      -1.467930 -1.467930
# 2         2.216891      0.324410     -0.267118      -0.652779 -0.652779
# 3        -0.835845     -0.060003     -0.204914       0.089064  0.089064
# 4        -0.193587     -0.107811     -0.508853      -0.065758 -0.065758
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb
# 0 -0.332304  -0.859361    -0.318702         -0.011695      -0.577303
# 1 -1.201107  -1.020477    -0.298595         -1.559757      -1.002757
# 2  0.489501  -0.919680    -0.415243          0.862119      -0.577303
# 3  0.278165  -1.084683    -0.298595         -0.750170       0.398415
# 4 -0.506874  -0.984066    -0.415243          0.586177      -0.577303

# %%
# train set, test set autogluon input dataset 으로 변경
train_data = TabularDataset(train_merge_f)
test_data = TabularDataset(x_test_merge_f)

# %% [markdown]
# ## 02) autogluon modeling

# %%
# 모델 서칭
save_path = 'aj_predictmodel2' # 모델.pkl 파일 저장 경로
predictor = TabularPredictor(label='uenomax', problem_type='regression', path=save_path, eval_metric='mean_absolute_error').fit(train_data, presets='best_quality', num_bag_folds=5, num_bag_sets=1) # 예측 모델 찾기
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="aj_predictmodel2"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (137445 samples, 36.29 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "aj_predictmodel2/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Jun 9 10:57:30 UTC 2023
# Disk Space Avail:   33.55 GB / 107.37 GB (31.2%)
# Train Data Rows:    137445
# Train Data Columns: 31
# Label Column: uenomax
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    52111.87 MB
# 	Train Data (Original)  Memory Usage: 34.09 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['numrar']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['numrar']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', [])   :  2 | ['reestabatt', 'reestabsucc']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', ['bool']) :  2 | ['reestabatt', 'reestabsucc']
# 	0.8s = Fit runtime
# 	30 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 31.06 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.85s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-1.0275	 = Validation score   (-mean_absolute_error)
# 	0.11s	 = Training   runtime
# 	23.57s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-1.0238	 = Validation score   (-mean_absolute_error)
# 	0.12s	 = Training   runtime
# 	23.72s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6437	 = Validation score   (-mean_absolute_error)
# 	148.67s	 = Training   runtime
# 	133.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6419	 = Validation score   (-mean_absolute_error)
# 	93.9s	 = Training   runtime
# 	37.47s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.6476	 = Validation score   (-mean_absolute_error)
# 	177.2s	 = Training   runtime
# 	8.44s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6361	 = Validation score   (-mean_absolute_error)
# 	442.46s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.6524	 = Validation score   (-mean_absolute_error)
# 	39.59s	 = Training   runtime
# 	8.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6782	 = Validation score   (-mean_absolute_error)
# 	211.06s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6468	 = Validation score   (-mean_absolute_error)
# 	44.39s	 = Training   runtime
# 	5.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6497	 = Validation score   (-mean_absolute_error)
# 	349.98s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6385	 = Validation score   (-mean_absolute_error)
# 	109.86s	 = Training   runtime
# 	46.72s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.6285	 = Validation score   (-mean_absolute_error)
# 	2.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6348	 = Validation score   (-mean_absolute_error)
# 	28.45s	 = Training   runtime
# 	8.76s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6305	 = Validation score   (-mean_absolute_error)
# 	10.21s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.6345	 = Validation score   (-mean_absolute_error)
# 	343.94s	 = Training   runtime
# 	9.97s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6325	 = Validation score   (-mean_absolute_error)
# 	73.86s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.6318	 = Validation score   (-mean_absolute_error)
# 	59.95s	 = Training   runtime
# 	9.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6389	 = Validation score   (-mean_absolute_error)
# 	223.12s	 = Training   runtime
# 	2.65s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6295	 = Validation score   (-mean_absolute_error)
# 	7.87s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6395	 = Validation score   (-mean_absolute_error)
# 	139.08s	 = Training   runtime
# 	1.55s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6318	 = Validation score   (-mean_absolute_error)
# 	20.45s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.6276	 = Validation score   (-mean_absolute_error)
# 	1.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2717.16s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("aj_predictmodel2/")

# %%
# best model load
predictor = TabularPredictor.load('aj_predictmodel2/')

# %%
# 개별 모델의 train 성능 확인
ld_board = predictor.leaderboard(train_data, silent=True)
ld_board=ld_board.sort_values(by='score_val',ascending=False)

# %%
ld_board
# Out:
#                      model    score_test  score_val  pred_time_test  \
# 9      WeightedEnsemble_L3 -4.951916e-01  -0.627559      363.203950
# 12     WeightedEnsemble_L2 -4.979247e-01  -0.628536      245.973893
# 14          XGBoost_BAG_L2 -5.034558e-01  -0.629452      321.440856
# 13         LightGBM_BAG_L2 -5.010171e-01  -0.630508      319.934978
# 6     LightGBMLarge_BAG_L2 -4.911636e-01  -0.631768      322.642261
# 5     ExtraTreesMSE_BAG_L2 -4.910376e-01  -0.631848      325.916983
# 10         CatBoost_BAG_L2 -4.961332e-01  -0.632454      318.286574
# 4   RandomForestMSE_BAG_L2 -4.887627e-01  -0.634455      322.928106
# 8        LightGBMXT_BAG_L2 -4.949593e-01  -0.634783      330.623857
# 17         CatBoost_BAG_L1 -5.522067e-01  -0.636120        1.260764
# 3     LightGBMLarge_BAG_L1 -4.341187e-01  -0.638549       58.835517
# 7   NeuralNetFastAI_BAG_L2 -4.939390e-01  -0.638906      334.035320
# 11   NeuralNetTorch_BAG_L2 -4.978897e-01  -0.639497      328.532661
# 15         LightGBM_BAG_L1 -5.074788e-01  -0.641888       53.274547
# 16       LightGBMXT_BAG_L1 -5.348441e-01  -0.643709      122.495880
# 18          XGBoost_BAG_L1 -5.575332e-01  -0.646847        6.802542
# 1   RandomForestMSE_BAG_L1 -3.344545e-01  -0.647587        6.730447
# 19   NeuralNetTorch_BAG_L1 -6.054782e-01  -0.649684        3.362692
# 2     ExtraTreesMSE_BAG_L1 -4.046783e-01  -0.652374        6.696649
# 20  NeuralNetFastAI_BAG_L1 -6.564748e-01  -0.678195       11.525340
# 0    KNeighborsDist_BAG_L1 -2.309141e-08  -1.023822       23.561781
# 21   KNeighborsUnif_BAG_L1 -8.311543e-01  -1.027458       23.373272
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 9      315.671498  2403.360620                 0.012198
# 12     227.457402  1324.266218                 0.014046
# 14     290.989713  1625.202433                 3.521426
# 13     291.511202  1627.541456                 2.015548
# 6      292.594837  1637.775005                 4.722830
# 5      299.696513  1677.275043                 7.997553
# 10     290.460847  1691.186514                 0.367144
# 4      300.317856  1961.271584                 5.008676
# 8      299.105845  1645.783119                12.704427
# 17       0.324276   442.458700                 1.260764
# 3       46.722257   109.858421                58.835517
# 7      292.996914  1840.452528                16.115890
# 11     291.897292  1756.409987                10.613230
# 15      37.466879    93.895170                53.274547
# 16     133.445999   148.665032               122.495880
# 18       5.053662    44.388542                 6.802542
# 1        8.444370   177.204220                 6.730447
# 19       1.050891   349.980480                 3.362692
# 2        8.129592    39.587136                 6.696649
# 20       2.414429   211.057163                11.525340
# 0       23.721567     0.118850                23.561781
# 21      23.574205     0.114643                23.373272
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 9                 0.002650           1.849376            3       True
# 12                0.002730           2.204195            2       True
# 14                0.641585           7.874076            2       True
# 13                1.163073          10.213099            2       True
# 6                 2.246709          20.446647            2       True
# 5                 9.348385          59.946685            2       True
# 10                0.112719          73.858156            2       True
# 4                 9.969727         343.943226            2       True
# 8                 8.757717          28.454762            2       True
# 17                0.324276         442.458700            1       True
# 3                46.722257         109.858421            1       True
# 7                 2.648785         223.124170            2       True
# 11                1.549164         139.081630            2       True
# 15               37.466879          93.895170            1       True
# 16              133.445999         148.665032            1       True
# 18                5.053662          44.388542            1       True
# 1                 8.444370         177.204220            1       True
# 19                1.050891         349.980480            1       True
# 2                 8.129592          39.587136            1       True
# 20                2.414429         211.057163            1       True
# 0                23.721567           0.118850            1       True
# 21               23.574205           0.114643            1       True
#
#     fit_order
# 9          22
# 12         12
# 14         19
# 13         14
# 6          21
# 5          17
# 10         16
# 4          15
# 8          13
# 17          6
# 3          11
# 7          18
# 11         20
# 15          4
# 16          3
# 18          9
# 1           5
# 19         10
# 2           7
# 20          8
# 0           2
# 21          1

# %%
# predict
y_test = predictor.predict(test_data)

# %%
y_test.head()
# Out:
# 0    2.428789
# 1    1.397500
# 2    3.464953
# 3    2.869492
# 4    3.046493
# Name: uenomax, dtype: float32

# %% [markdown]
# ## 03) make submit file

# %%
# x_test + y_test
test = pd.read_csv('raw_data/Q1_test.csv')
pred = test.loc[:,['ru_id']]
pred['pred'] = y_test

# make submit file
submit = pd.read_csv('raw_data/Q1_label_sample.csv')
submit['BaseStationB']=pred.loc[pred['ru_id']=='BaseStationB',['pred']].reset_index(drop=True)
submit['BaseStationJ']=pred.loc[pred['ru_id']=='BaseStationJ',['pred']].reset_index(drop=True)

# 함수 돌리기 전에 순서바꿔야함
submit.to_csv('submission_data/submit2.csv')
submit.head()
# Out:
#               datetime  BaseStationB  BaseStationJ
# 0  2023-05-19 00:00:00      1.397500      2.428789
# 1  2023-05-19 00:05:00      2.869492      3.464953
# 2  2023-05-19 00:10:00      2.683626      3.046493
# 3  2023-05-19 00:15:00      2.165024      3.529145
# 4  2023-05-19 00:20:00      2.393902      4.188874

# %% [markdown]
# ## 제출 결과 : 1.2805663609점

# %% [markdown]
# # Submit3 : 상관관계 높은 컬럼 사용 / 로그 스케일링 / 로버스트 스케일링

# %% [markdown]
# ## 01) data set load

# %%
train_merge_f = pd.read_csv('preprocessed_data/submit3_train.csv', index_col=0)
x_test_merge_f = pd.read_csv('preprocessed_data/submit3_test.csv', index_col=0)

# %%
train_merge_f.head()
# Out:
#    scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0      0.0   -0.884523    -0.884523   -0.206003    -0.206003
# 1      0.0    0.103093     0.103093    0.438540     0.438540
# 2      1.0   -0.603499    -0.603499   -0.542636    -0.542636
# 3      0.0   -0.912489    -0.912489   -0.834044    -0.834044
# 4      0.0    0.528462     0.528462    0.695977     0.695977
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -1.482307          -1.000000         -2.734545          -2.734545
# 1          1.014162           1.261860          0.773047           0.765527
# 2          0.417311           0.442507         -0.833803          -0.833803
# 3          0.000000           0.000000         -1.630930          -1.464974
# 4          1.000000           1.000000          0.460209           0.460209
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0     -0.306270      -0.306270                           0.0
# 1     -0.834044      -0.834044                           0.0
# 2     -1.571069      -1.571069                           1.0
# 3      0.630930       0.630930                           0.0
# 4     -0.553295      -0.553295                           0.0
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                           0.0    -1.160964     -1.160964         0.0
# 1                           0.0    -0.630930     -0.630930         0.0
# 2                           0.0    -1.261860     -1.261860         0.0
# 3                           0.0     0.000000      0.000000         0.0
# 4                           0.0     1.000000      1.000000         0.0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0          0.0  -3.670964  -4.399198    -1.095376    -0.718677
# 1          0.0   0.026671   0.284699     0.000000     0.199207
# 2          0.0   0.459742   0.172017     0.383373     0.093114
# 3          0.0  -0.353912  -0.439983     0.000000     0.000000
# 4          0.0   0.041314   0.524792     0.000000     0.498862
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -0.400000     -2.629482     -3.209006      -0.865209 -0.865209
# 1        -0.666667     -0.193652      0.305302       0.751982  0.751982
# 2         1.000000      0.474570      0.071059      -0.383695 -0.383695
# 3        -0.714286     -0.526745     -0.585510       1.576382  1.576382
# 4        -0.400000     -0.020114      0.533280       0.324553  0.324553
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb  uenomax
# 0 -1.090766  -0.542940         -0.7         -0.818182      -0.500000        1
# 1  0.147612  -0.544025         -0.4         -0.533333       0.834044        5
# 2 -0.572062  -0.571689         -0.6         -0.300000      -0.602888        6
# 3 -0.439174  -0.466526         -2.0          0.758621       0.000000        1
# 4  0.489374  -0.555705         -1.0          1.500000       0.684582        4

# %%
x_test_merge_f.head()
# Out:
#    scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0      0.0   -0.369070    -0.369070   -0.244077    -0.244077
# 1      0.0   -1.298091    -1.298091   -1.362611    -1.362611
# 2      0.0   -0.738140    -0.738140   -0.832160    -0.832160
# 3      0.0    0.201181     0.201181    0.310133     0.310133
# 4      0.0   -0.535026    -0.535026   -0.398763    -0.398763
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0          0.000000            0.00000         -1.062875          -1.140314
# 1         -0.710382           -0.63093         -1.247567          -1.247567
# 2          0.000000            0.00000         -0.285471          -0.306270
# 3         -0.710382           -0.63093          0.231563           0.231563
# 4          0.000000            0.00000         -0.718868          -0.771244
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0       0.00000        0.00000                           0.0
# 1       0.00000        0.00000                           0.0
# 2       0.00000        0.00000                           0.0
# 3       0.00000        0.00000                           0.0
# 4       0.36907        0.36907                           0.0
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                           0.0     0.693147      0.693147         0.0
# 1                           0.0     0.000000      0.000000         0.0
# 2                           0.0     0.000000      0.000000         0.0
# 3                           0.0     0.000000      0.000000         0.0
# 4                           0.0     0.000000      0.000000         0.0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0          0.0  -1.071590  -1.365561          0.0     0.000000
# 1          0.0  -0.985529  -1.334135          0.0    -0.513164
# 2          0.0   0.197840  -0.360217          0.0     0.000000
# 3          0.0  -0.041050  -0.338622          0.0    -0.513164
# 4          0.0   0.029231  -0.464549          0.0     0.000000
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -1.666667     -0.491706     -0.361872       0.187483  0.187483
# 1         0.200000     -1.451921     -1.475730      -1.390743 -1.390743
# 2         3.333333      0.130214     -0.359057      -0.507757 -0.507757
# 3        -0.800000     -0.152850     -0.379105      -0.054164 -0.054164
# 4        -0.333333     -0.159881     -0.518627      -0.110899 -0.110899
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb
# 0 -0.337180  -0.466526         -1.5         -0.035714       0.000000
# 1 -1.185885  -0.555705         -1.0         -1.428571      -0.876759
# 2  0.328393  -0.497886         -2.0          0.642857       0.000000
# 3  0.061810  -0.588724         -1.0         -0.714286       0.223472
# 4 -0.478564  -0.531360         -2.0          0.428571       0.000000

# %%
# train set, test set autogluon input dataset 으로 변경
train_data = TabularDataset(train_merge_f)
test_data = TabularDataset(x_test_merge_f)

# %% [markdown]
# ## 02) autogluon modeling

# %%
# 모델 서칭
save_path = 'aj_predictmodel3' # 모델.pkl 파일 저장 경로
predictor = TabularPredictor(label='uenomax', problem_type='regression', path=save_path, eval_metric='mean_absolute_error').fit(train_data, presets='best_quality', num_bag_folds=5, num_bag_sets=1) # 예측 모델 찾기
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="aj_predictmodel3"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (137445 samples, 36.29 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "aj_predictmodel3/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Jun 9 10:57:30 UTC 2023
# Disk Space Avail:   33.54 GB / 107.37 GB (31.2%)
# Train Data Rows:    137445
# Train Data Columns: 31
# Label Column: uenomax
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    51478.9 MB
# 	Train Data (Original)  Memory Usage: 34.09 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['numrar']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['numrar']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 30 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', ['bool']) :  2 | ['reestabatt', 'reestabsucc']
# 	0.9s = Fit runtime
# 	30 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 31.06 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.96s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-1.0182	 = Validation score   (-mean_absolute_error)
# 	0.1s	 = Training   runtime
# 	23.3s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-1.0158	 = Validation score   (-mean_absolute_error)
# 	0.1s	 = Training   runtime
# 	23.83s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6941	 = Validation score   (-mean_absolute_error)
# 	214.78s	 = Training   runtime
# 	402.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6685	 = Validation score   (-mean_absolute_error)
# 	159.29s	 = Training   runtime
# 	86.2s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.7049	 = Validation score   (-mean_absolute_error)
# 	181.18s	 = Training   runtime
# 	8.65s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6605	 = Validation score   (-mean_absolute_error)
# 	662.84s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.7643	 = Validation score   (-mean_absolute_error)
# 	44.58s	 = Training   runtime
# 	8.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.7668	 = Validation score   (-mean_absolute_error)
# 	212.8s	 = Training   runtime
# 	2.45s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6729	 = Validation score   (-mean_absolute_error)
# 	238.23s	 = Training   runtime
# 	27.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.7258	 = Validation score   (-mean_absolute_error)
# 	596.88s	 = Training   runtime
# 	1.12s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6669	 = Validation score   (-mean_absolute_error)
# 	234.77s	 = Training   runtime
# 	155.91s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.6495	 = Validation score   (-mean_absolute_error)
# 	2.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6479	 = Validation score   (-mean_absolute_error)
# 	47.98s	 = Training   runtime
# 	17.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6455	 = Validation score   (-mean_absolute_error)
# 	14.37s	 = Training   runtime
# 	1.58s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.648	 = Validation score   (-mean_absolute_error)
# 	322.81s	 = Training   runtime
# 	9.72s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6463	 = Validation score   (-mean_absolute_error)
# 	130.98s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.6459	 = Validation score   (-mean_absolute_error)
# 	57.91s	 = Training   runtime
# 	9.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6515	 = Validation score   (-mean_absolute_error)
# 	207.6s	 = Training   runtime
# 	2.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6451	 = Validation score   (-mean_absolute_error)
# 	17.58s	 = Training   runtime
# 	1.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.7726	 = Validation score   (-mean_absolute_error)
# 	79.85s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6452	 = Validation score   (-mean_absolute_error)
# 	22.84s	 = Training   runtime
# 	2.68s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.6418	 = Validation score   (-mean_absolute_error)
# 	1.92s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3738.87s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("aj_predictmodel3/")

# %%
# best model load
predictor = TabularPredictor.load('aj_predictmodel3/')

# %%
# 개별 모델의 train 성능 확인
ld_board = predictor.leaderboard(train_data, silent=True)
ld_board=ld_board.sort_values(by='score_val',ascending=False)

# %%
ld_board
# Out:
#                      model    score_test  score_val  pred_time_test  \
# 8      WeightedEnsemble_L3 -4.655779e-01  -0.641770      667.095204
# 14          XGBoost_BAG_L2 -4.782557e-01  -0.645147      635.906660
# 12    LightGBMLarge_BAG_L2 -4.715883e-01  -0.645202      637.452406
# 13         LightGBM_BAG_L2 -4.780481e-01  -0.645476      635.753711
# 4     ExtraTreesMSE_BAG_L2 -4.592588e-01  -0.645891      640.506251
# 10         CatBoost_BAG_L2 -4.685131e-01  -0.646259      633.996556
# 9        LightGBMXT_BAG_L2 -4.677781e-01  -0.647852      657.758095
# 6   RandomForestMSE_BAG_L2 -4.651909e-01  -0.647971      641.492032
# 7      WeightedEnsemble_L2 -4.655169e-01  -0.649500      307.613405
# 11  NeuralNetFastAI_BAG_L2 -4.694311e-01  -0.651496      644.727851
# 17         CatBoost_BAG_L1 -5.275217e-01  -0.660546        2.296932
# 1     LightGBMLarge_BAG_L1 -3.062047e-01  -0.666908      153.956441
# 3          LightGBM_BAG_L1 -4.350322e-01  -0.668466      109.238238
# 15          XGBoost_BAG_L1 -4.895604e-01  -0.672928       31.231503
# 16       LightGBMXT_BAG_L1 -5.145693e-01  -0.694099      260.812232
# 2   RandomForestMSE_BAG_L1 -3.659467e-01  -0.704901        7.440950
# 19   NeuralNetTorch_BAG_L1 -6.314079e-01  -0.725783        3.432738
# 5     ExtraTreesMSE_BAG_L1 -4.630458e-01  -0.764302        6.466946
# 20  NeuralNetFastAI_BAG_L1 -7.359553e-01  -0.766776       11.566700
# 18   NeuralNetTorch_BAG_L2 -5.700442e-01  -0.772567      639.167104
# 0    KNeighborsDist_BAG_L1 -8.148607e-09  -1.015791       23.294502
# 21   KNeighborsUnif_BAG_L1 -8.259027e-01  -1.018195       23.662595
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 8      764.853093  3307.180932                 0.012337
# 14     740.813404  2563.128344                 2.506882
# 12     742.411726  2568.388685                 4.052628
# 13     741.314408  2559.924522                 2.353933
# 4      748.909875  2603.460072                 7.106473
# 10     739.890941  2676.529166                 0.596778
# 9      756.833251  2593.534142                24.358317
# 6      749.454596  2868.363803                 8.092254
# 7      279.749870  2075.378418                 0.016603
# 11     742.018849  2753.153746                11.328073
# 17       0.571695   662.841055                 2.296932
# 1      155.910743   234.766604               153.956441
# 3       86.200357   159.293609               109.238238
# 15      27.287092   238.233743                31.231503
# 16     402.020828   214.780374               260.812232
# 2        8.652259   181.176138                 7.440950
# 19       1.124573   596.878864                 3.432738
# 5        8.383283    44.579840                 6.466946
# 20       2.452444   212.799940                11.566700
# 18     741.297785  2625.408192                 5.767326
# 0       23.830829     0.102580                23.294502
# 21      23.295785     0.100481                23.662595
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 8                 0.003140           1.923252            3       True
# 14                1.083516          17.575116            2       True
# 12                2.681839          22.835457            2       True
# 13                1.584521          14.371295            2       True
# 4                 9.179987          57.906844            2       True
# 10                0.161053         130.975939            2       True
# 9                17.103363          47.980915            2       True
# 6                 9.724708         322.810576            2       True
# 7                 0.003151           2.188406            2       True
# 11                2.288961         207.600519            2       True
# 17                0.571695         662.841055            1       True
# 1               155.910743         234.766604            1       True
# 3                86.200357         159.293609            1       True
# 15               27.287092         238.233743            1       True
# 16              402.020828         214.780374            1       True
# 2                 8.652259         181.176138            1       True
# 19                1.124573         596.878864            1       True
# 5                 8.383283          44.579840            1       True
# 20                2.452444         212.799940            1       True
# 18                1.567897          79.854965            2       True
# 0                23.830829           0.102580            1       True
# 21               23.295785           0.100481            1       True
#
#     fit_order
# 8          22
# 14         19
# 12         21
# 13         14
# 4          17
# 10         16
# 9          13
# 6          15
# 7          12
# 11         18
# 17          6
# 1          11
# 3           4
# 15          9
# 16          3
# 2           5
# 19         10
# 5           7
# 20          8
# 18         20
# 0           2
# 21          1

# %%
# predict
y_test = predictor.predict(test_data)

# %%
y_test.head()
# Out:
# 0    1.847958
# 1    1.302597
# 2    1.580923
# 3    2.798252
# 4    1.586574
# Name: uenomax, dtype: float32

# %% [markdown]
# ## 03) make submit file

# %%
# x_test + y_test
test = pd.read_csv('raw_data/Q1_test.csv')
pred = test.loc[:,['ru_id']]
pred['pred'] = y_test

# make submit file
submit = pd.read_csv('raw_data/Q1_label_sample.csv')
submit['BaseStationB']=pred.loc[pred['ru_id']=='BaseStationB',['pred']].reset_index(drop=True)
submit['BaseStationJ']=pred.loc[pred['ru_id']=='BaseStationJ',['pred']].reset_index(drop=True)

# 함수 돌리기 전에 순서바꿔야함
submit.to_csv('submission_data/submit3.csv')
submit.head()
# Out:
#               datetime  BaseStationB  BaseStationJ
# 0  2023-05-19 00:00:00      1.302597      1.847958
# 1  2023-05-19 00:05:00      2.798252      1.580923
# 2  2023-05-19 00:10:00      2.796225      1.586574
# 3  2023-05-19 00:15:00      1.908340      1.499048
# 4  2023-05-19 00:20:00      2.418369      1.868755

# %% [markdown]
# ## 제출 결과 : 0.7865075409점

# %% [markdown]
# # Submit4 : 모든 컬럼 사용 / 로그 스케일링 / 로버스트 스케일링

# %% [markdown]
# ## 01) data set load

# %%
train_merge_f = pd.read_csv('preprocessed_data/submit4_train.csv', index_col=0)
x_test_merge_f = pd.read_csv('preprocessed_data/submit4_test.csv', index_col=0)

# %%
train_merge_f.head()
# Out:
#    scgfail  scgfailratio  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0      0.0      0.000000   -0.884523    -0.884523   -0.206003    -0.206003
# 1      0.0      0.000000    0.103093     0.103093    0.438540     0.438540
# 2      1.0      1.503043   -0.603499    -0.603499   -0.542636    -0.542636
# 3      0.0      0.000000   -0.912489    -0.912489   -0.834044    -0.834044
# 4      0.0      0.000000    0.528462     0.528462    0.695977     0.695977
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -1.482307          -1.000000         -2.734545          -2.734545
# 1          1.014162           1.261860          0.773047           0.765527
# 2          0.417311           0.442507         -0.833803          -0.833803
# 3          0.000000           0.000000         -1.630930          -1.464974
# 4          1.000000           1.000000          0.460209           0.460209
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0     -0.306270      -0.306270                           0.0
# 1     -0.834044      -0.834044                           0.0
# 2     -1.571069      -1.571069                           1.0
# 3      0.630930       0.630930                           0.0
# 4     -0.553295      -0.553295                           0.0
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                           0.0    -1.160964     -1.160964         0.0
# 1                           0.0    -0.630930     -0.630930         0.0
# 2                           0.0    -1.261860     -1.261860         0.0
# 3                           0.0     0.000000      0.000000         0.0
# 4                           0.0     1.000000      1.000000         0.0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0          0.0  -3.670964  -4.399198    -1.095376    -0.718677
# 1          0.0   0.026671   0.284699     0.000000     0.199207
# 2          0.0   0.459742   0.172017     0.383373     0.093114
# 3          0.0  -0.353912  -0.439983     0.000000     0.000000
# 4          0.0   0.041314   0.524792     0.000000     0.498862
#
#    dlreceivedriavg  dltransmittedmcsavg  airmaculbyte  airmacdlbyte   bler_ul  \
# 0        -0.400000            -1.483871     -2.629482     -3.209006 -1.887552
# 1        -0.666667             0.548387     -0.193652      0.305302  0.394987
# 2         1.000000            -0.321429      0.474570      0.071059 -0.600397
# 3        -0.714286            -0.220000     -0.526745     -0.585510 -1.176345
# 4        -0.400000             0.978261     -0.020114      0.533280  0.857415
#
#     bler_dl  rachpreamblea    numrar   nummsg3  attpaging  rssipathavg  \
# 0  1.659999      -0.865209 -0.865209 -1.090766  -0.542940         -0.7
# 1  0.304229       0.751982  0.751982  0.147612  -0.544025         -0.4
# 2 -0.400374      -0.383695 -0.383695 -0.572062  -0.571689         -0.6
# 3 -0.133592       1.576382  1.576382 -0.439174  -0.466526         -2.0
# 4  0.107598       0.324553  0.324553  0.489374  -0.555705         -1.0
#
#    dlreceivedcqiavg  endcrelbymenb  uenomax
# 0         -0.818182      -0.500000        1
# 1         -0.533333       0.834044        5
# 2         -0.300000      -0.602888        6
# 3          0.758621       0.000000        1
# 4          1.500000       0.684582        4

# %%
x_test_merge_f.head()
# Out:
#    scgfail  scgfailratio  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0      0.0           0.0   -0.369070    -0.369070   -0.244077    -0.244077
# 1      0.0           0.0   -1.298091    -1.298091   -1.362611    -1.362611
# 2      0.0           0.0   -0.738140    -0.738140   -0.832160    -0.832160
# 3      0.0           0.0    0.201181     0.201181    0.310133     0.310133
# 4      0.0           0.0   -0.535026    -0.535026   -0.398763    -0.398763
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0          0.000000            0.00000         -1.062875          -1.140314
# 1         -0.710382           -0.63093         -1.247567          -1.247567
# 2          0.000000            0.00000         -0.285471          -0.306270
# 3         -0.710382           -0.63093          0.231563           0.231563
# 4          0.000000            0.00000         -0.718868          -0.771244
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0       0.00000        0.00000                           0.0
# 1       0.00000        0.00000                           0.0
# 2       0.00000        0.00000                           0.0
# 3       0.00000        0.00000                           0.0
# 4       0.36907        0.36907                           0.0
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                           0.0     0.693147      0.693147         0.0
# 1                           0.0     0.000000      0.000000         0.0
# 2                           0.0     0.000000      0.000000         0.0
# 3                           0.0     0.000000      0.000000         0.0
# 4                           0.0     0.000000      0.000000         0.0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0          0.0  -1.071590  -1.365561          0.0     0.000000
# 1          0.0  -0.985529  -1.334135          0.0    -0.513164
# 2          0.0   0.197840  -0.360217          0.0     0.000000
# 3          0.0  -0.041050  -0.338622          0.0    -0.513164
# 4          0.0   0.029231  -0.464549          0.0     0.000000
#
#    dlreceivedriavg  dltransmittedmcsavg  airmaculbyte  airmacdlbyte   bler_ul  \
# 0        -1.666667             0.038462     -0.491706     -0.361872 -0.345020
# 1         0.200000            -0.815385     -1.451921     -1.475730 -6.045324
# 2         3.333333            -0.615385      0.130214     -0.359057  1.732271
# 3        -0.800000            -0.138462     -0.152850     -0.379105 -0.261025
# 4        -0.333333            -0.576923     -0.159881     -0.518627 -0.394908
#
#     bler_dl  rachpreamblea    numrar   nummsg3  attpaging  rssipathavg  \
# 0  0.743185       0.187483  0.187483 -0.337180  -0.466526         -1.5
# 1 -1.689675      -1.390743 -1.390743 -1.185885  -0.555705         -1.0
# 2 -0.404324      -0.507757 -0.507757  0.328393  -0.497886         -2.0
# 3 -1.206677      -0.054164 -0.054164  0.061810  -0.588724         -1.0
# 4 -0.827277      -0.110899 -0.110899 -0.478564  -0.531360         -2.0
#
#    dlreceivedcqiavg  endcrelbymenb
# 0         -0.035714       0.000000
# 1         -1.428571      -0.876759
# 2          0.642857       0.000000
# 3         -0.714286       0.223472
# 4          0.428571       0.000000

# %%
# train set, test set autogluon input dataset 으로 변경
train_data = TabularDataset(train_merge_f)
test_data = TabularDataset(x_test_merge_f)

# %% [markdown]
# ## 02) autogluon modeling

# %%
# 모델 서칭
save_path = 'aj_predictmodel4' # 모델.pkl 파일 저장 경로
predictor = TabularPredictor(label='uenomax', problem_type='regression', path=save_path, eval_metric='mean_absolute_error').fit(train_data, presets='best_quality', num_bag_folds=5, num_bag_sets=1) # 예측 모델 찾기
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="aj_predictmodel4"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (137445 samples, 40.68 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "aj_predictmodel4/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Jun 9 10:57:30 UTC 2023
# Disk Space Avail:   33.54 GB / 107.37 GB (31.2%)
# Train Data Rows:    137445
# Train Data Columns: 35
# Label Column: uenomax
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    50283.68 MB
# 	Train Data (Original)  Memory Usage: 38.48 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['numrar']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['numrar']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 34 | ['scgfail', 'scgfailratio', 'erabaddatt', 'erabaddsucc', 'endcaddatt', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 32 | ['scgfail', 'scgfailratio', 'erabaddatt', 'erabaddsucc', 'endcaddatt', ...]
# 		('int', ['bool']) :  2 | ['reestabatt', 'reestabsucc']
# 	1.1s = Fit runtime
# 	34 features in original data used to generate 34 features in processed data.
# 	Train Data (Processed) Memory Usage: 35.46 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-1.0054	 = Validation score   (-mean_absolute_error)
# 	0.15s	 = Training   runtime
# 	24.33s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-1.0027	 = Validation score   (-mean_absolute_error)
# 	0.13s	 = Training   runtime
# 	24.76s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.678	 = Validation score   (-mean_absolute_error)
# 	242.73s	 = Training   runtime
# 	367.35s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6542	 = Validation score   (-mean_absolute_error)
# 	199.08s	 = Training   runtime
# 	96.51s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.6992	 = Validation score   (-mean_absolute_error)
# 	207.98s	 = Training   runtime
# 	9.02s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6452	 = Validation score   (-mean_absolute_error)
# 	694.39s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.7559	 = Validation score   (-mean_absolute_error)
# 	52.37s	 = Training   runtime
# 	8.8s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.7452	 = Validation score   (-mean_absolute_error)
# 	224.57s	 = Training   runtime
# 	2.44s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.66	 = Validation score   (-mean_absolute_error)
# 	259.79s	 = Training   runtime
# 	31.31s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.7474	 = Validation score   (-mean_absolute_error)
# 	422.65s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6512	 = Validation score   (-mean_absolute_error)
# 	339.21s	 = Training   runtime
# 	180.43s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.6355	 = Validation score   (-mean_absolute_error)
# 	2.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6334	 = Validation score   (-mean_absolute_error)
# 	52.07s	 = Training   runtime
# 	16.24s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6314	 = Validation score   (-mean_absolute_error)
# 	16.45s	 = Training   runtime
# 	2.02s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.6332	 = Validation score   (-mean_absolute_error)
# 	360.51s	 = Training   runtime
# 	10.03s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6318	 = Validation score   (-mean_absolute_error)
# 	121.05s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.6313	 = Validation score   (-mean_absolute_error)
# 	64.57s	 = Training   runtime
# 	9.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6455	 = Validation score   (-mean_absolute_error)
# 	219.33s	 = Training   runtime
# 	2.71s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6312	 = Validation score   (-mean_absolute_error)
# 	14.01s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.7703	 = Validation score   (-mean_absolute_error)
# 	103.14s	 = Training   runtime
# 	1.55s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6307	 = Validation score   (-mean_absolute_error)
# 	24.23s	 = Training   runtime
# 	2.68s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.6279	 = Validation score   (-mean_absolute_error)
# 	1.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3941.77s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("aj_predictmodel4/")

# %%
# best model load
predictor = TabularPredictor.load('aj_predictmodel4/')

# %%
# 개별 모델의 train 성능 확인
ld_board = predictor.leaderboard(train_data, silent=True)
ld_board=ld_board.sort_values(by='score_val',ascending=False)

# %%
ld_board
# Out:
#                      model    score_test  score_val  pred_time_test  \
# 8      WeightedEnsemble_L3 -4.360084e-01  -0.627885      725.047854
# 9     LightGBMLarge_BAG_L2 -4.374177e-01  -0.630687      683.714861
# 13          XGBoost_BAG_L2 -4.495812e-01  -0.631193      683.704768
# 6     ExtraTreesMSE_BAG_L2 -4.312111e-01  -0.631269      684.355785
# 11         LightGBM_BAG_L2 -4.441086e-01  -0.631367      682.611529
# 10         CatBoost_BAG_L2 -4.388774e-01  -0.631779      679.267575
# 7   RandomForestMSE_BAG_L2 -4.345377e-01  -0.633242      683.839644
# 4        LightGBMXT_BAG_L2 -4.287661e-01  -0.633357      704.113003
# 5      WeightedEnsemble_L2 -4.299119e-01  -0.635482      351.841859
# 17         CatBoost_BAG_L1 -5.093162e-01  -0.645169        2.438476
# 12  NeuralNetFastAI_BAG_L2 -4.450907e-01  -0.645496      696.718956
# 1     LightGBMLarge_BAG_L1 -2.687560e-01  -0.651235      170.114695
# 3          LightGBM_BAG_L1 -4.032480e-01  -0.654181      117.498221
# 15          XGBoost_BAG_L1 -4.597026e-01  -0.659967       38.081686
# 16       LightGBMXT_BAG_L1 -4.835122e-01  -0.678009      268.201586
# 2   RandomForestMSE_BAG_L1 -3.548689e-01  -0.699154        7.746797
# 20  NeuralNetFastAI_BAG_L1 -7.089783e-01  -0.745214       12.095815
# 19   NeuralNetTorch_BAG_L1 -6.677342e-01  -0.747357        3.851920
# 14    ExtraTreesMSE_BAG_L1 -4.523656e-01  -0.755912        7.484094
# 18   NeuralNetTorch_BAG_L2 -5.794149e-01  -0.770262      692.445463
# 0    KNeighborsDist_BAG_L1 -6.055487e-08  -1.002688       25.387483
# 21   KNeighborsUnif_BAG_L1 -8.153909e-01  -1.005422       25.892372
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 8      785.986719  3281.411934                 0.017936
# 9      749.470597  2667.263183                 4.921717
# 13     747.562471  2657.042248                 4.911625
# 6      756.112643  2707.603001                 5.562641
# 11     748.807235  2659.485950                 3.818386
# 10     746.943654  2764.088429                 0.474431
# 7      756.819993  3003.546662                 5.046500
# 4      763.032351  2695.106725                25.319860
# 5      321.556837  2349.879792                 0.014251
# 17       0.657790   694.387546                 2.438476
# 12     749.505224  2862.361409                17.925812
# 1      180.434373   339.208213               170.114695
# 3       96.505821   199.083000               117.498221
# 15      31.308069   259.786436                38.081686
# 16     367.354273   242.725010               268.201586
# 2        9.022921   207.977010                 7.746797
# 20       2.439031   224.570114                12.095815
# 19       1.186012   422.650145                 3.851920
# 14       8.798451    52.368265                 7.484094
# 18     748.341497  2746.169651                13.652319
# 0       24.758982     0.133176                25.387483
# 21      24.325836     0.145214                25.892372
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 8                 0.002804           1.932332            3       True
# 9                 2.679038          24.229053            2       True
# 13                0.770912          14.008119            2       True
# 6                 9.321084          64.568872            2       True
# 11                2.015676          16.451821            2       True
# 10                0.152095         121.054300            2       True
# 7                10.028434         360.512532            2       True
# 4                16.240793          52.072596            2       True
# 5                 0.002820           2.217328            2       True
# 17                0.657790         694.387546            1       True
# 12                2.713665         219.327280            2       True
# 1               180.434373         339.208213            1       True
# 3                96.505821         199.083000            1       True
# 15               31.308069         259.786436            1       True
# 16              367.354273         242.725010            1       True
# 2                 9.022921         207.977010            1       True
# 20                2.439031         224.570114            1       True
# 19                1.186012         422.650145            1       True
# 14                8.798451          52.368265            1       True
# 18                1.549938         103.135522            2       True
# 0                24.758982           0.133176            1       True
# 21               24.325836           0.145214            1       True
#
#     fit_order
# 8          22
# 9          21
# 13         19
# 6          17
# 11         14
# 10         16
# 7          15
# 4          13
# 5          12
# 17          6
# 12         18
# 1          11
# 3           4
# 15          9
# 16          3
# 2           5
# 20          8
# 19         10
# 14          7
# 18         20
# 0           2
# 21          1

# %%
# predict
y_test = predictor.predict(test_data)

# %%
y_test.head()
# Out:
# 0    1.893983
# 1    1.232111
# 2    1.713050
# 3    2.864348
# 4    1.637138
# Name: uenomax, dtype: float32

# %% [markdown]
# ## 03) make submit file

# %%
# x_test + y_test
test = pd.read_csv('raw_data/Q1_test.csv')
pred = test.loc[:,['ru_id']]
pred['pred'] = y_test

# make submit file
submit = pd.read_csv('raw_data/Q1_label_sample.csv')
submit['BaseStationB']=pred.loc[pred['ru_id']=='BaseStationB',['pred']].reset_index(drop=True)
submit['BaseStationJ']=pred.loc[pred['ru_id']=='BaseStationJ',['pred']].reset_index(drop=True)

# 함수 돌리기 전에 순서바꿔야함
submit.to_csv('submission_data/submit4.csv')
submit.head()
# Out:
#               datetime  BaseStationB  BaseStationJ
# 0  2023-05-19 00:00:00      1.232111      1.893983
# 1  2023-05-19 00:05:00      2.864348      1.713050
# 2  2023-05-19 00:10:00      2.918217      1.637138
# 3  2023-05-19 00:15:00      1.941319      1.544662
# 4  2023-05-19 00:20:00      2.447587      2.013840

# %% [markdown]
# ## 제출 결과 : 0.8005025288점

# %% [markdown]
# # Submit5 : 모든 컬럼 사용 / 로그 스케일링 / 로버스트 스케일링 / 차분 후 이동평균 feature 추가

# %% [markdown]
# ## Stage 1 : test set의 이동평균모형(moving_average) 예측

# %% [markdown]
# ### 01) data set load

# %%
train_merge_f = pd.read_csv('preprocessed_data/submit5_train.csv', index_col=0)
x_test_merge_f = pd.read_csv('preprocessed_data/submit5_test.csv', index_col=0)

# %%
train_merge_f.head()
# Out:
#      scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 19 -0.406465    0.354394     0.354647    0.492939     0.493019
# 20 -0.561473   -0.026324    -0.026161    0.082987     0.083100
# 21 -0.521983    0.086961     0.087599   -0.014509    -0.014115
# 22 -0.605127   -0.277835    -0.277737   -0.329298    -0.329280
# 23  1.232606   -0.189232    -0.188962    0.043767     0.043860
#
#     endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 19         -0.826929          -0.781595         -0.555948          -0.549283
# 20         -0.802317          -0.743494         -0.386390          -0.377104
# 21         -1.412955          -1.252297          0.609088           0.622151
# 22          0.921948           0.811282          0.043453           0.047080
# 23         -0.148437          -0.363585         -0.720159          -0.714240
#
#     connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 19      1.005675       1.008167                     -0.312775
# 20     -0.279667      -0.277644                     -0.246645
# 21      0.875024       0.876645                     -0.316598
# 22      0.917552       0.918158                     -0.434171
# 23      0.767531       0.768990                     -0.263516
#
#     redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 19                     -0.183432    -0.688403     -0.687824           0
# 20                     -0.207081     1.623207      1.623434           0
# 21                     -0.155505    -0.440922     -0.439731           0
# 22                     -0.310128     1.122019      1.127556           0
# 23                     -0.286459     1.286370      1.288383           0
#
#     reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 19            0  -1.008692  -1.298108    -0.544307    -0.590302
# 20            0  -0.148612   0.582296    -0.955251    -0.654832
# 21            0  -0.332495   0.613014    -0.387238     0.719185
# 22            0   0.174133   0.726444    -0.722408     1.433786
# 23            0   0.747192   0.855584     1.044322     2.673322
#
#     dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 19        -0.377691     -0.688100     -1.155042      -0.278979 -0.278979
# 20        -1.065858     -0.159705      0.568791      -0.370003 -0.370003
# 21        -0.314893     -0.368698      0.623522       0.422150  0.422150
# 22        -0.338203      0.198020      0.660083       0.259042  0.259042
# 23        -0.510557      0.701621      0.797717      -0.860446 -0.860446
#
#      nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb  \
# 19  0.410375  -0.984066    -2.259611          0.395832      -0.575646
# 20 -0.080685  -1.111763    -1.546140          2.130529       0.334132
# 21  0.135509  -1.111744    -1.762692         -1.272567       0.285279
# 22  0.253013  -1.111719    -0.919822          0.354786      -0.680861
# 23  0.128012  -1.302677    -0.749490         -2.335046      -0.088507
#
#     uenomax  seasonal_diff  moving_average
# 19        1            0.0        0.166667
# 20        2           -2.0       -0.083333
# 21        5            2.0        0.166667
# 22        3            1.0        0.166667
# 23        2            1.0        0.250000

# %%
x_test_merge_f.head()
# Out:
#     scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0 -0.667542   -0.481082    -0.480596   -0.257629    -0.257425
# 1 -0.427040   -1.454413    -1.453854   -1.349899    -1.349338
# 2 -0.667542   -1.004315    -1.003808   -1.144738    -1.144495
# 3 -0.427040    0.447827     0.448464    0.530739     0.531318
# 4 -0.667542   -0.716359    -0.715864   -0.490970    -0.490755
#
#    endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 0         -0.718056          -0.670180         -1.382757          -1.379720
# 1         -1.000441          -0.916495         -1.413417          -1.410143
# 2         -0.718056          -0.670180         -0.328479          -0.324267
# 3         -1.000441          -0.916495          0.464955           0.470439
# 4         -0.718056          -0.670180         -0.916231          -0.912675
#
#    connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 0      0.010077       0.011238                     -0.226592
# 1     -0.469494      -0.468596                     -0.128414
# 2      0.010077       0.011238                     -0.226592
# 3     -0.469494      -0.468596                     -0.128414
# 4      0.573040       0.574515                     -0.226592
#
#    redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 0                     -0.171584     1.982971      1.987162           0
# 1                     -0.086296    -0.447929     -0.447758           0
# 2                     -0.171584    -0.323645     -0.322739           0
# 3                     -0.086296    -0.447929     -0.447758           0
# 4                     -0.171584    -0.323645     -0.322739           0
#
#    reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 0            0  -1.562210  -1.751742    -0.410825    -0.523185
# 1            0  -1.509133  -1.624831    -0.469801    -0.633370
# 2            0   0.529450  -0.234396    -0.410825    -0.523185
# 3            0   0.132145  -0.138808    -0.469801    -0.633370
# 4            0   0.251629  -0.391863    -0.410825    -0.523185
#
#    dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 0        -1.070125     -0.602207     -0.271383       0.375598  0.375598
# 1         0.278680     -1.920447     -1.815504      -1.467930 -1.467930
# 2         2.216891      0.324410     -0.267118      -0.652779 -0.652779
# 3        -0.835845     -0.060003     -0.204914       0.089064  0.089064
# 4        -0.193587     -0.107811     -0.508853      -0.065758 -0.065758
#
#     nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb
# 0 -0.332304  -0.859361    -0.318702         -0.011695      -0.577303
# 1 -1.201107  -1.020477    -0.298595         -1.559757      -1.002757
# 2  0.489501  -0.919680    -0.415243          0.862119      -0.577303
# 3  0.278165  -1.084683    -0.298595         -0.750170       0.398415
# 4 -0.506874  -0.984066    -0.415243          0.586177      -0.577303

# %%
sea_xtrain = train_merge_f.drop(['uenomax', 'seasonal_diff' ], axis = 1)

# %%
sea_xtrain.head()
# Out:
#      scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 19 -0.406465    0.354394     0.354647    0.492939     0.493019
# 20 -0.561473   -0.026324    -0.026161    0.082987     0.083100
# 21 -0.521983    0.086961     0.087599   -0.014509    -0.014115
# 22 -0.605127   -0.277835    -0.277737   -0.329298    -0.329280
# 23  1.232606   -0.189232    -0.188962    0.043767     0.043860
#
#     endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  endcmodbysgnbsucc  \
# 19         -0.826929          -0.781595         -0.555948          -0.549283
# 20         -0.802317          -0.743494         -0.386390          -0.377104
# 21         -1.412955          -1.252297          0.609088           0.622151
# 22          0.921948           0.811282          0.043453           0.047080
# 23         -0.148437          -0.363585         -0.720159          -0.714240
#
#     connestabatt  connestabsucc  redirectiontolte_coverageout  \
# 19      1.005675       1.008167                     -0.312775
# 20     -0.279667      -0.277644                     -0.246645
# 21      0.875024       0.876645                     -0.316598
# 22      0.917552       0.918158                     -0.434171
# 23      0.767531       0.768990                     -0.263516
#
#     redirectiontolte_epsfallback  handoveratt  handoversucc  reestabatt  \
# 19                     -0.183432    -0.688403     -0.687824           0
# 20                     -0.207081     1.623207      1.623434           0
# 21                     -0.155505    -0.440922     -0.439731           0
# 22                     -0.310128     1.122019      1.127556           0
# 23                     -0.286459     1.286370      1.288383           0
#
#     reestabsucc  rlculbyte  rlcdlbyte  totprbulavg  totprbdlavg  \
# 19            0  -1.008692  -1.298108    -0.544307    -0.590302
# 20            0  -0.148612   0.582296    -0.955251    -0.654832
# 21            0  -0.332495   0.613014    -0.387238     0.719185
# 22            0   0.174133   0.726444    -0.722408     1.433786
# 23            0   0.747192   0.855584     1.044322     2.673322
#
#     dlreceivedriavg  airmaculbyte  airmacdlbyte  rachpreamblea    numrar  \
# 19        -0.377691     -0.688100     -1.155042      -0.278979 -0.278979
# 20        -1.065858     -0.159705      0.568791      -0.370003 -0.370003
# 21        -0.314893     -0.368698      0.623522       0.422150  0.422150
# 22        -0.338203      0.198020      0.660083       0.259042  0.259042
# 23        -0.510557      0.701621      0.797717      -0.860446 -0.860446
#
#      nummsg3  attpaging  rssipathavg  dlreceivedcqiavg  endcrelbymenb  \
# 19  0.410375  -0.984066    -2.259611          0.395832      -0.575646
# 20 -0.080685  -1.111763    -1.546140          2.130529       0.334132
# 21  0.135509  -1.111744    -1.762692         -1.272567       0.285279
# 22  0.253013  -1.111719    -0.919822          0.354786      -0.680861
# 23  0.128012  -1.302677    -0.749490         -2.335046      -0.088507
#
#     moving_average
# 19        0.166667
# 20       -0.083333
# 21        0.166667
# 22        0.166667
# 23        0.250000

# %%
# train set, test set autogluon input dataset 으로 변경
train_data = TabularDataset(sea_xtrain)
test_data = TabularDataset(x_test_merge_f)

# %% [markdown]
# ### 02) autogluon modeling

# %%
# 모델 서칭
save_path = 'aj_movingaverage' # 모델.pkl 파일 저장 경로
predictor = TabularPredictor(label='moving_average', problem_type='regression', path=save_path, eval_metric='mean_absolute_error').fit(train_data, presets='best_quality', num_bag_folds=5, num_bag_sets=1) # 예측 모델 찾기
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="aj_movingaverage"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (113413 samples, 29.94 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "aj_movingaverage/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Jun 9 10:57:30 UTC 2023
# Disk Space Avail:   33.54 GB / 107.37 GB (31.2%)
# Train Data Rows:    113413
# Train Data Columns: 31
# Label Column: moving_average
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    50275.21 MB
# 	Train Data (Original)  Memory Usage: 28.13 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 2): ['reestabsucc', 'numrar']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['numrar']
# 		('int', [])   : 1 | ['reestabsucc']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', [])   :  1 | ['reestabatt']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 28 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', ['bool']) :  1 | ['reestabatt']
# 	0.8s = Fit runtime
# 	29 features in original data used to generate 29 features in processed data.
# 	Train Data (Processed) Memory Usage: 25.52 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.91s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.3685	 = Validation score   (-mean_absolute_error)
# 	0.08s	 = Training   runtime
# 	16.74s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.3688	 = Validation score   (-mean_absolute_error)
# 	0.11s	 = Training   runtime
# 	16.05s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3312	 = Validation score   (-mean_absolute_error)
# 	10.06s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3311	 = Validation score   (-mean_absolute_error)
# 	6.37s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.3346	 = Validation score   (-mean_absolute_error)
# 	170.77s	 = Training   runtime
# 	6.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.331	 = Validation score   (-mean_absolute_error)
# 	18.75s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.3334	 = Validation score   (-mean_absolute_error)
# 	37.76s	 = Training   runtime
# 	5.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3329	 = Validation score   (-mean_absolute_error)
# 	175.33s	 = Training   runtime
# 	2.28s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.331	 = Validation score   (-mean_absolute_error)
# 	7.24s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3318	 = Validation score   (-mean_absolute_error)
# 	121.17s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3313	 = Validation score   (-mean_absolute_error)
# 	9.31s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.3307	 = Validation score   (-mean_absolute_error)
# 	1.91s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3309	 = Validation score   (-mean_absolute_error)
# 	6.47s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3309	 = Validation score   (-mean_absolute_error)
# 	7.27s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.333	 = Validation score   (-mean_absolute_error)
# 	414.54s	 = Training   runtime
# 	8.19s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3309	 = Validation score   (-mean_absolute_error)
# 	8.11s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.3324	 = Validation score   (-mean_absolute_error)
# 	59.99s	 = Training   runtime
# 	7.62s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3308	 = Validation score   (-mean_absolute_error)
# 	186.69s	 = Training   runtime
# 	1.96s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.331	 = Validation score   (-mean_absolute_error)
# 	7.84s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.331	 = Validation score   (-mean_absolute_error)
# 	107.55s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.3311	 = Validation score   (-mean_absolute_error)
# 	11.78s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.3306	 = Validation score   (-mean_absolute_error)
# 	1.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1484.87s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("aj_movingaverage/")

# %%
# best model load
predictor = TabularPredictor.load('aj_movingaverage/')

# %%
# 개별 모델의 train 성능 확인
ld_board = predictor.leaderboard(train_data, silent=True)
ld_board=ld_board.sort_values(by='score_val',ascending=False)

# %%
ld_board
# Out:
#                      model  score_test  score_val  pred_time_test  \
# 8      WeightedEnsemble_L3   -0.313338  -0.330602       90.084834
# 10     WeightedEnsemble_L2   -0.317330  -0.330728       26.786048
# 6   NeuralNetFastAI_BAG_L2   -0.311992  -0.330802       73.624297
# 12         CatBoost_BAG_L2   -0.317966  -0.330872       63.801575
# 13       LightGBMXT_BAG_L2   -0.319587  -0.330887       64.694132
# 14         LightGBM_BAG_L2   -0.319983  -0.330898       64.484013
# 19         CatBoost_BAG_L1   -0.328362  -0.330967        0.220574
# 11   NeuralNetTorch_BAG_L2   -0.317388  -0.331002       67.663399
# 16          XGBoost_BAG_L1   -0.326065  -0.331037        1.353238
# 7           XGBoost_BAG_L2   -0.312388  -0.331037       65.700561
# 18         LightGBM_BAG_L1   -0.327421  -0.331058        1.127107
# 9     LightGBMLarge_BAG_L2   -0.317056  -0.331082       65.049988
# 17       LightGBMXT_BAG_L1   -0.327414  -0.331174        2.671708
# 15    LightGBMLarge_BAG_L1   -0.321922  -0.331314        1.597981
# 20   NeuralNetTorch_BAG_L1   -0.329369  -0.331771        2.840006
# 4     ExtraTreesMSE_BAG_L2   -0.306475  -0.332398       67.519839
# 21  NeuralNetFastAI_BAG_L1   -0.330099  -0.332918        9.322322
# 5   RandomForestMSE_BAG_L2   -0.310624  -0.332972       67.842074
# 2     ExtraTreesMSE_BAG_L1   -0.198174  -0.333368        5.934707
# 1   RandomForestMSE_BAG_L1   -0.166075  -0.334552        5.974829
# 3    KNeighborsUnif_BAG_L1   -0.301086  -0.368490       16.418234
# 0    KNeighborsDist_BAG_L1   -0.000007  -0.368791       16.174491
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 8       72.764100  1354.236461                 0.011857
# 10      16.195137   539.293040                 0.013263
# 6       53.809651   743.640421                 9.989098
# 12      51.922128   565.065344                 0.166376
# 13      52.426831   563.428150                 1.058933
# 14      52.341867   564.223774                 0.848814
# 19       0.069215    18.753000                 0.220574
# 11      53.020085   664.500797                 4.028200
# 16       0.652805     7.238509                 1.353238
# 7       52.454417   564.799276                 2.065362
# 18       0.729837     6.366268                 1.127107
# 9       52.725190   568.732177                 1.414789
# 17       1.803491    10.059170                 2.671708
# 15       1.068497     9.314251                 1.597981
# 20       0.826977   121.168044                 2.840006
# 4       59.471144   616.939535                 3.884640
# 21       2.277768   175.331790                 9.322322
# 5       60.038656   971.492649                 4.206875
# 2        5.543630    37.759197                 5.934707
# 1        6.092714   170.769101                 5.974829
# 3       16.736207     0.083805                16.418234
# 0       16.048789     0.111225                16.174491
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 8                 0.002666           1.634002            3       True
# 10                0.002191           1.907129            2       True
# 6                 1.959722         186.686060            2       True
# 12                0.072199           8.110982            2       True
# 13                0.576901           6.473789            2       True
# 14                0.491937           7.269413            2       True
# 19                0.069215          18.753000            1       True
# 11                1.170156         107.546435            2       True
# 16                0.652805           7.238509            1       True
# 7                 0.604488           7.844914            2       True
# 18                0.729837           6.366268            1       True
# 9                 0.875260          11.777815            2       True
# 17                1.803491          10.059170            1       True
# 15                1.068497           9.314251            1       True
# 20                0.826977         121.168044            1       True
# 4                 7.621215          59.985173            2       True
# 21                2.277768         175.331790            1       True
# 5                 8.188726         414.538287            2       True
# 2                 5.543630          37.759197            1       True
# 1                 6.092714         170.769101            1       True
# 3                16.736207           0.083805            1       True
# 0                16.048789           0.111225            1       True
#
#     fit_order
# 8          22
# 10         12
# 6          18
# 12         16
# 13         13
# 14         14
# 19          6
# 11         20
# 16          9
# 7          19
# 18          4
# 9          21
# 17          3
# 15         11
# 20         10
# 4          17
# 21          8
# 5          15
# 2           7
# 1           5
# 3           1
# 0           2

# %%
# predict
y_test = predictor.predict(test_data)

# %%
y_test.head()
# Out:
# 0    0.001258
# 1   -0.032343
# 2    0.026395
# 3    0.041967
# 4    0.028460
# Name: moving_average, dtype: float32

# %% [markdown]
# ### 03) test set에 moving_average feature 추가

# %%
test_dta = test_data.copy()
test_dta['moving_average'] = y_test

# %%
test_dta
# Out:
#         scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 0     -0.667542   -0.481082    -0.480596   -0.257629    -0.257425
# 1     -0.427040   -1.454413    -1.453854   -1.349899    -1.349338
# 2     -0.667542   -1.004315    -1.003808   -1.144738    -1.144495
# 3     -0.427040    0.447827     0.448464    0.530739     0.531318
# 4     -0.667542   -0.716359    -0.715864   -0.490970    -0.490755
# ...         ...         ...          ...         ...          ...
# 34357  1.532271    0.368125     0.368759    0.368058     0.368636
# 34358 -0.667542   -0.109843    -0.109371    0.110554     0.110743
# 34359 -0.427040    0.522972     0.523613    0.451942     0.452521
# 34360 -0.667542    0.612314     0.612758    0.731920     0.732082
# 34361 -0.427040    0.786791     0.787442    0.865853     0.866436
#
#        endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  \
# 0             -0.718056          -0.670180         -1.382757
# 1             -1.000441          -0.916495         -1.413417
# 2             -0.718056          -0.670180         -0.328479
# 3             -1.000441          -0.916495          0.464955
# 4             -0.718056          -0.670180         -0.916231
# ...                 ...                ...               ...
# 34357          0.810988           0.658130          0.701703
# 34358         -0.718056          -0.670180         -1.382757
# 34359          1.124914           1.070460          1.265812
# 34360         -0.718056          -0.670180          0.058664
# 34361          0.286365           0.076983          1.122191
#
#        endcmodbysgnbsucc  connestabatt  connestabsucc  \
# 0              -1.379720      0.010077       0.011238
# 1              -1.410143     -0.469494      -0.468596
# 2              -0.324267      0.010077       0.011238
# 3               0.470439     -0.469494      -0.468596
# 4              -0.912675      0.573040       0.574515
# ...                  ...           ...            ...
# 34357           0.707465     -0.469494      -0.468596
# 34358          -1.379720     -0.952314      -0.951689
# 34359           1.272238     -0.469494      -0.468596
# 34360           0.063307      0.573040       0.574515
# 34361           1.128448      2.890957       2.898668
#
#        redirectiontolte_coverageout  redirectiontolte_epsfallback  \
# 0                         -0.226592                     -0.171584
# 1                         -0.128414                     -0.086296
# 2                         -0.226592                     -0.171584
# 3                         -0.128414                     -0.086296
# 4                         -0.226592                     -0.171584
# ...                             ...                           ...
# 34357                     -0.128414                     -0.086296
# 34358                     -0.226592                     -0.171584
# 34359                     -0.128414                     -0.086296
# 34360                     -0.226592                     -0.171584
# 34361                     -0.128414                     -0.086296
#
#        handoveratt  handoversucc  reestabatt  reestabsucc  rlculbyte  \
# 0         1.982971      1.987162           0            0  -1.562210
# 1        -0.447929     -0.447758           0            0  -1.509133
# 2        -0.323645     -0.322739           0            0   0.529450
# 3        -0.447929     -0.447758           0            0   0.132145
# 4        -0.323645     -0.322739           0            0   0.251629
# ...            ...           ...         ...          ...        ...
# 34357    -0.447929     -0.447758           0            0   0.127206
# 34358    -0.323645     -0.322739           0            0  -0.215680
# 34359    -0.447929     -0.447758           0            0   0.106777
# 34360    -0.323645     -0.322739           0            0  -0.103053
# 34361     1.127406      1.128767           0            0  -0.324408
#
#        rlcdlbyte  totprbulavg  totprbdlavg  dlreceivedriavg  airmaculbyte  \
# 0      -1.751742    -0.410825    -0.523185        -1.070125     -0.602207
# 1      -1.624831    -0.469801    -0.633370         0.278680     -1.920447
# 2      -0.234396    -0.410825    -0.523185         2.216891      0.324410
# 3      -0.138808    -0.469801    -0.633370        -0.835845     -0.060003
# 4      -0.391863    -0.410825    -0.523185        -0.193587     -0.107811
# ...          ...          ...          ...              ...           ...
# 34357  -0.087128    -0.469801    -0.257831         0.278680     -0.171032
# 34358  -0.174460    -0.410825    -0.523185         0.244682     -0.602207
# 34359   0.821717    -0.469801     0.437326         0.724490     -0.163275
# 34360  -0.787735    -0.410825    -0.523185        -0.193587     -0.389456
# 34361   0.777125    -0.469801     0.098440         0.724490     -0.372767
#
#        airmacdlbyte  rachpreamblea    numrar   nummsg3  attpaging  \
# 0         -0.271383       0.375598  0.375598 -0.332304  -0.859361
# 1         -1.815504      -1.467930 -1.467930 -1.201107  -1.020477
# 2         -0.267118      -0.652779 -0.652779  0.489501  -0.919680
# 3         -0.204914       0.089064  0.089064  0.278165  -1.084683
# 4         -0.508853      -0.065758 -0.065758 -0.506874  -0.984066
# ...             ...            ...       ...       ...        ...
# 34357     -0.153268       0.212320  0.212320  0.412612   1.863996
# 34358     -0.288326       0.760466  0.760466 -0.332304   1.878725
# 34359      0.803051       0.212320  0.212320  0.412612   1.872295
# 34360     -0.872964       0.030453  0.030453  0.573875   2.088826
# 34361      0.758427       0.919118  0.919118  0.837374   2.018178
#
#        rssipathavg  dlreceivedcqiavg  endcrelbymenb  moving_average
# 0        -0.318702         -0.011695      -0.577303        0.001258
# 1        -0.298595         -1.559757      -1.002757       -0.032343
# 2        -0.415243          0.862119      -0.577303        0.026395
# 3        -0.298595         -0.750170       0.398415        0.041967
# 4        -0.415243          0.586177      -0.577303        0.028460
# ...            ...               ...            ...             ...
# 34357     0.090991         -0.912087       0.310422        0.061120
# 34358    -0.029079          0.540187      -0.577303        0.026227
# 34359     0.772766         -0.966060       0.398415        0.070592
# 34360     0.067462          0.678158      -0.577303        0.085644
# 34361     0.285784         -0.642225       0.943578        0.037974
#
# [34362 rows x 32 columns]

# %% [markdown]
# ## Stage 2 : test set의 target(uenomax) 예측

# %% [markdown]
# ### 01) train set에 기존 train set의 index로 target('uenomax') 추가

# %%
# 수정된 train set
sea_xtrain_t = sea_xtrain.copy()

# 붙일 target 변수
tar = train_merge_f.loc[:, 'uenomax']

# train set에 target 변수 추가
sea_xtrain_t['uenomax'] = tar

# %%
sea_xtrain_t
# Out:
#          scgfail  erabaddatt  erabaddsucc  endcaddatt  endcaddsucc  \
# 19     -0.406465    0.354394     0.354647    0.492939     0.493019
# 20     -0.561473   -0.026324    -0.026161    0.082987     0.083100
# 21     -0.521983    0.086961     0.087599   -0.014509    -0.014115
# 22     -0.605127   -0.277835    -0.277737   -0.329298    -0.329280
# 23      1.232606   -0.189232    -0.188962    0.043767     0.043860
# ...          ...         ...          ...         ...          ...
# 137431 -0.670763    0.238136     0.238423   -0.697900    -0.697832
# 137437  1.089254    0.514000     0.514366    0.816927     0.817073
# 137440  2.031058   -0.301652    -0.301403   -0.163554    -0.163474
# 137442 -0.521983    0.227076     0.227708    0.143675     0.144069
# 137443  1.023248   -0.651568    -0.651450   -0.589706    -0.589691
#
#         endcmodbymenbatt  endcmodbymenbsucc  endcmodbysgnbatt  \
# 19             -0.826929          -0.781595         -0.555948
# 20             -0.802317          -0.743494         -0.386390
# 21             -1.412955          -1.252297          0.609088
# 22              0.921948           0.811282          0.043453
# 23             -0.148437          -0.363585         -0.720159
# ...                  ...                ...               ...
# 137431          0.612832           0.631136          0.070188
# 137437          1.394304           1.788079          0.635208
# 137440         -0.826929          -0.781595         -1.021776
# 137442          0.663566           0.546714         -0.314773
# 137443         -0.961457          -0.856636         -0.494579
#
#         endcmodbysgnbsucc  connestabatt  connestabsucc  \
# 19              -0.549283      1.005675       1.008167
# 20              -0.377104     -0.279667      -0.277644
# 21               0.622151      0.875024       0.876645
# 22               0.047080      0.917552       0.918158
# 23              -0.714240      0.767531       0.768990
# ...                   ...           ...            ...
# 137431           0.035298      1.419520       1.423413
# 137437           0.651939      0.921490       0.925966
# 137440          -1.015858     -0.982390      -0.981255
# 137442          -0.571641      1.814054       1.815895
# 137443          -0.491212      0.301767       0.302299
#
#         redirectiontolte_coverageout  redirectiontolte_epsfallback  \
# 19                         -0.312775                     -0.183432
# 20                         -0.246645                     -0.207081
# 21                         -0.316598                     -0.155505
# 22                         -0.434171                     -0.310128
# 23                         -0.263516                     -0.286459
# ...                              ...                           ...
# 137431                      1.000958                      1.664328
# 137437                     -0.418631                      2.765298
# 137440                     -0.312775                     -0.183432
# 137442                      2.830195                     -0.155505
# 137443                      1.140271                     -0.310128
#
#         handoveratt  handoversucc  reestabatt  reestabsucc  rlculbyte  \
# 19        -0.688403     -0.687824           0            0  -1.008692
# 20         1.623207      1.623434           0            0  -0.148612
# 21        -0.440922     -0.439731           0            0  -0.332495
# 22         1.122019      1.127556           0            0   0.174133
# 23         1.286370      1.288383           0            0   0.747192
# ...             ...           ...         ...          ...        ...
# 137431     0.917318      0.923125           0            0   0.424183
# 137437     0.396290      0.400208           0            0   0.174152
# 137440     0.841217      0.842257           0            0  -1.008692
# 137442    -0.440922     -0.439731           0            0   0.186566
# 137443    -0.535983     -0.534879           0            0  -0.466656
#
#         rlcdlbyte  totprbulavg  totprbdlavg  dlreceivedriavg  airmaculbyte  \
# 19      -1.298108    -0.544307    -0.590302        -0.377691     -0.688100
# 20       0.582296    -0.955251    -0.654832        -1.065858     -0.159705
# 21       0.613014    -0.387238     0.719185        -0.314893     -0.368698
# 22       0.726444    -0.722408     1.433786        -0.338203      0.198020
# 23       0.855584     1.044322     2.673322        -0.510557      0.701621
# ...           ...          ...          ...              ...           ...
# 137431   0.004399     0.787134    -0.188178         0.687495      0.844085
# 137437  -0.059989    -0.191296    -0.615876         1.171733      0.052529
# 137440  -0.907988    -0.544307    -0.590302         0.284577     -0.343893
# 137442   0.144946    -0.387238    -0.431759        -0.314893      0.049908
# 137443  -0.966558    -0.722408    -0.861240        -0.502572     -0.391003
#
#         airmacdlbyte  rachpreamblea    numrar   nummsg3  attpaging  \
# 19         -1.155042      -0.278979 -0.278979  0.410375  -0.984066
# 20          0.568791      -0.370003 -0.370003 -0.080685  -1.111763
# 21          0.623522       0.422150  0.422150  0.135509  -1.111744
# 22          0.660083       0.259042  0.259042  0.253013  -1.111719
# 23          0.797717      -0.860446 -0.860446  0.128012  -1.302677
# ...              ...            ...       ...       ...        ...
# 137431      0.236163       0.602736  0.602736  0.807792   1.817827
# 137437     -0.181625       0.563675  0.563675  1.235115   1.834157
# 137440     -0.381625       0.887608  0.887608 -0.935714   2.088826
# 137442      0.104228       0.236891  0.236891  0.562804   2.018318
# 137443     -0.945953      -0.103606 -0.103606 -0.493490   2.018406
#
#         rssipathavg  dlreceivedcqiavg  endcrelbymenb  moving_average  uenomax
# 19        -2.259611          0.395832      -0.575646        0.166667        1
# 20        -1.546140          2.130529       0.334132       -0.083333        2
# 21        -1.762692         -1.272567       0.285279        0.166667        5
# 22        -0.919822          0.354786      -0.680861        0.166667        3
# 23        -0.749490         -2.335046      -0.088507        0.250000        2
# ...             ...               ...            ...             ...      ...
# 137431     0.627705          1.081933       0.140567        0.166667        7
# 137437    -0.058104          0.669103       0.452049        0.333333        4
# 137440     1.772095          0.187796      -0.575646       -0.083333        1
# 137442     1.016026          0.015750       0.352772       -0.166667        3
# 137443     0.453272          0.874905      -0.867418       -0.250000        2
#
# [113413 rows x 33 columns]

# %% [markdown]
# ### 02) make data set

# %%
xtrain_t = sea_xtrain_t.copy()
test_dta_t = test_dta.copy()

# %%
# train set, test set autogluon input dataset 으로 변경
train_data = TabularDataset(xtrain_t)
test_data = TabularDataset(test_dta_t)

# %% [markdown]
# ### 03) autogluon modeling

# %%
# 모델 서칭
save_path = 'predict_t_1' # 모델.pkl 파일 저장 경로
predictor = TabularPredictor(label='uenomax', problem_type='regression', path=save_path, eval_metric='mean_absolute_error').fit(train_data, presets='best_quality', num_bag_folds=5, num_bag_sets=1) # 예측 모델 찾기
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (113413 samples, 30.85 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "predict_t_1/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Fri Jun 9 10:57:30 UTC 2023
# Disk Space Avail:   33.54 GB / 107.37 GB (31.2%)
# Train Data Rows:    113413
# Train Data Columns: 32
# Label Column: uenomax
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    49998.78 MB
# 	Train Data (Original)  Memory Usage: 29.03 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 2): ['reestabsucc', 'numrar']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['numrar']
# 		('int', [])   : 1 | ['reestabsucc']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 29 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', [])   :  1 | ['reestabatt']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 29 | ['scgfail', 'erabaddatt', 'erabaddsucc', 'endcaddatt', 'endcaddsucc', ...]
# 		('int', ['bool']) :  1 | ['reestabatt']
# 	0.9s = Fit runtime
# 	30 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 26.43 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.94s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.9945	 = Validation score   (-mean_absolute_error)
# 	0.1s	 = Training   runtime
# 	16.16s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.9914	 = Validation score   (-mean_absolute_error)
# 	0.09s	 = Training   runtime
# 	17.18s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6095	 = Validation score   (-mean_absolute_error)
# 	87.08s	 = Training   runtime
# 	64.25s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6083	 = Validation score   (-mean_absolute_error)
# 	44.68s	 = Training   runtime
# 	20.55s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.6153	 = Validation score   (-mean_absolute_error)
# 	144.29s	 = Training   runtime
# 	6.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6025	 = Validation score   (-mean_absolute_error)
# 	277.81s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.6195	 = Validation score   (-mean_absolute_error)
# 	31.9s	 = Training   runtime
# 	6.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6273	 = Validation score   (-mean_absolute_error)
# 	174.53s	 = Training   runtime
# 	2.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6097	 = Validation score   (-mean_absolute_error)
# 	32.64s	 = Training   runtime
# 	5.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5818	 = Validation score   (-mean_absolute_error)
# 	695.48s	 = Training   runtime
# 	0.87s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.6072	 = Validation score   (-mean_absolute_error)
# 	54.6s	 = Training   runtime
# 	24.69s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.5802	 = Validation score   (-mean_absolute_error)
# 	1.76s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5995	 = Validation score   (-mean_absolute_error)
# 	15.16s	 = Training   runtime
# 	2.94s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5976	 = Validation score   (-mean_absolute_error)
# 	9.08s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.6026	 = Validation score   (-mean_absolute_error)
# 	274.19s	 = Training   runtime
# 	7.67s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5981	 = Validation score   (-mean_absolute_error)
# 	25.39s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.6	 = Validation score   (-mean_absolute_error)
# 	48.46s	 = Training   runtime
# 	7.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5938	 = Validation score   (-mean_absolute_error)
# 	173.72s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.595	 = Validation score   (-mean_absolute_error)
# 	6.59s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.5791	 = Validation score   (-mean_absolute_error)
# 	428.94s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.599	 = Validation score   (-mean_absolute_error)
# 	18.99s	 = Training   runtime
# 	1.89s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.5786	 = Validation score   (-mean_absolute_error)
# 	1.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2684.81s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("predict_t_1/")

# %%
# best model load
predictor = TabularPredictor.load('predict_t_1/')

# %%
# 개별 모델의 train 성능 확인
ld_board = predictor.leaderboard(train_data, silent=True)
ld_board=ld_board.sort_values(by='score_val',ascending=False)

# %%
ld_board
# Out:
#                      model    score_test  score_val  pred_time_test  \
# 4      WeightedEnsemble_L3 -4.415637e-01  -0.578639      222.690067
# 3    NeuralNetTorch_BAG_L2 -4.407314e-01  -0.579098      209.330200
# 15     WeightedEnsemble_L2 -5.046395e-01  -0.580221       17.598181
# 17   NeuralNetTorch_BAG_L1 -5.134909e-01  -0.581789        3.508707
# 11  NeuralNetFastAI_BAG_L2 -4.779207e-01  -0.593798      213.929851
# 13          XGBoost_BAG_L2 -4.854395e-01  -0.594998      207.035449
# 12         LightGBM_BAG_L2 -4.836634e-01  -0.597553      206.675699
# 8          CatBoost_BAG_L2 -4.702084e-01  -0.598120      205.189949
# 10    LightGBMLarge_BAG_L2 -4.746578e-01  -0.599036      207.891852
# 9        LightGBMXT_BAG_L2 -4.743815e-01  -0.599495      209.575874
# 6     ExtraTreesMSE_BAG_L2 -4.670885e-01  -0.599975      209.299202
# 19         CatBoost_BAG_L1 -5.258831e-01  -0.602517        0.962124
# 7   RandomForestMSE_BAG_L2 -4.677717e-01  -0.602632      212.519602
# 5     LightGBMLarge_BAG_L1 -4.519687e-01  -0.607202       35.792896
# 14         LightGBM_BAG_L1 -5.028421e-01  -0.608294       28.391208
# 16       LightGBMXT_BAG_L1 -5.111412e-01  -0.609514       74.010291
# 18          XGBoost_BAG_L1 -5.248114e-01  -0.609723        7.074194
# 1   RandomForestMSE_BAG_L1 -2.874762e-01  -0.615317        6.041213
# 2     ExtraTreesMSE_BAG_L1 -3.535247e-01  -0.619538        3.927258
# 20  NeuralNetFastAI_BAG_L1 -6.032612e-01  -0.627327       12.904489
# 0    KNeighborsDist_BAG_L1 -1.869228e-08  -0.991392       16.416907
# 21   KNeighborsUnif_BAG_L1 -8.055179e-01  -0.994547       15.909058
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 4      174.223144  2195.876349                 0.007505
# 3      164.797806  1972.132483                 4.391854
# 15      12.580487  1151.983137                 0.011943
# 17       0.870879   695.476951                 3.508707
# 11     165.866955  1716.915729                 8.991505
# 13     164.150532  1549.780105                 2.097103
# 12     164.498021  1552.276820                 1.737354
# 8      163.690456  1568.586954                 0.251603
# 10     165.513994  1562.188786                 2.953506
# 9      166.565034  1558.357745                 4.637528
# 6      170.798653  1591.651596                 4.360857
# 19       0.227590   277.810495                 0.962124
# 7      171.289275  1817.382988                 7.581256
# 5       24.690556    54.600868                35.792896
# 14      20.545078    44.678050                28.391208
# 16      64.250524    87.076304                74.010291
# 18       5.272435    32.644405                 7.074194
# 1        6.207200   144.290602                 6.041213
# 2        6.138857    31.896956                 3.927258
# 20       2.083400   174.532805                12.904489
# 0       17.175004     0.086038                16.416907
# 21      16.159749     0.100925                15.909058
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 4                 0.002274           1.565339            3       True
# 3                 1.176534         428.938084            2       True
# 15                0.002383           1.760685            2       True
# 17                0.870879         695.476951            1       True
# 11                2.245683         173.721330            2       True
# 13                0.529260           6.585706            2       True
# 12                0.876750           9.082422            2       True
# 8                 0.069185          25.392556            2       True
# 10                1.892722          18.994387            2       True
# 9                 2.943762          15.163347            2       True
# 6                 7.177381          48.457197            2       True
# 19                0.227590         277.810495            1       True
# 7                 7.668003         274.188590            2       True
# 5                24.690556          54.600868            1       True
# 14               20.545078          44.678050            1       True
# 16               64.250524          87.076304            1       True
# 18                5.272435          32.644405            1       True
# 1                 6.207200         144.290602            1       True
# 2                 6.138857          31.896956            1       True
# 20                2.083400         174.532805            1       True
# 0                17.175004           0.086038            1       True
# 21               16.159749           0.100925            1       True
#
#     fit_order
# 4          22
# 3          20
# 15         12
# 17         10
# 11         18
# 13         19
# 12         14
# 8          16
# 10         21
# 9          13
# 6          17
# 19          6
# 7          15
# 5          11
# 14          4
# 16          3
# 18          9
# 1           5
# 2           7
# 20          8
# 0           2
# 21          1

# %%
# predict
y_test = predictor.predict(test_data)

# %%
y_test.head()
# Out:
# 0    3.073051
# 1    1.345345
# 2    3.900595
# 3    3.110903
# 4    3.768381
# Name: uenomax, dtype: float32

# %% [markdown]
# ## 03) make submit file

# %%
# x_test + y_test
test = pd.read_csv('raw_data/Q1_test.csv')
pred = test.loc[:,['ru_id']]
pred['pred'] = y_test

# make submit file
submit = pd.read_csv('raw_data/Q1_label_sample.csv')
submit['BaseStationB']=pred.loc[pred['ru_id']=='BaseStationB',['pred']].reset_index(drop=True)
submit['BaseStationJ']=pred.loc[pred['ru_id']=='BaseStationJ',['pred']].reset_index(drop=True)

# 함수 돌리기 전에 순서바꿔야함
submit.to_csv('submission_data/submit5.csv')
submit.head()
# Out:
#               datetime  BaseStationB  BaseStationJ
# 0  2023-05-19 00:00:00      1.345345      3.073051
# 1  2023-05-19 00:05:00      3.110903      3.900595
# 2  2023-05-19 00:10:00      3.162115      3.768381
# 3  2023-05-19 00:15:00      2.964196      3.794328
# 4  2023-05-19 00:20:00      3.057208      4.416271

# %% [markdown]
# ## 제출 결과 : 0.7658398103점

# %% [markdown]
# # 느낀 점

# %% [markdown]
# 최종 0.7658398103점으로 전체 311팀 중 48위
